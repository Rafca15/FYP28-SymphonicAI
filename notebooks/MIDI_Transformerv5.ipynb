# %%
"""Notebook implementing Transformer model trained on MIDI data."""

# %%
# !unzip /content/DATASET_AUGMENTED.zip -d /content/DATASET_AUGMENTED/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73973.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73973_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73973_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73973_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73981.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73981_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73981_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73981_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73982.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73982_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73982_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73982_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73995.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73995_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73995_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/73995_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740356.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740356_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740356_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740356_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740371.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740371_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740371_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740371_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740376.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740376_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740376_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740376_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74048.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74048_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74048_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74048_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740631.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740631_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740631_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/740631_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74077.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74077_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74077_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74077_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74092.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74092_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74092_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74092_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74099.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74099_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74099_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74099_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741041.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741041_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741041_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741041_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741181.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741181_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741181_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741181_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741186.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741186_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741186_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741186_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741261.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741261_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741261_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/741261_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74157.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74157_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74157_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74157_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742236.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742236_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742236_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742236_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742486.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742486_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742486_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742486_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742571.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742571_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742571_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742571_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74262.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74262_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74262_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74262_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74263.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74263_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74263_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74263_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74264.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742641.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742641_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742641_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742641_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74264_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74264_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74264_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742881.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742881_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742881_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/742881_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74334.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74334_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74334_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74334_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743431.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743431_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743431_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743431_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743531.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743531_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743531_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743531_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/743_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744161.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744161_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744161_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744161_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744191.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744191_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744191_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744191_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744296.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744296_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744296_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744296_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74455.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74455_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74455_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74455_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744581.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744581_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744581_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744581_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744586.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744586_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744586_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/744586_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74505.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74505_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74505_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74505_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74511.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74511_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74511_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74511_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74524.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74524_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74524_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74524_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745326.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745326_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745326_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745326_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745821.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745821_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745821_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745821_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745826.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745826_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745826_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/745826_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74658.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74658_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74658_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74658_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74701.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74701_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74701_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74701_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747236.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747236_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747236_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747236_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747541.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747541_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747541_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747541_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747561.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747561_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747561_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/747561_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748246.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748246_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748246_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748246_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748261.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748261_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748261_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748261_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748276.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748276_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748276_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748276_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748311.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748311_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748311_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748311_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748316.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748316_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748316_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748316_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748321.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748321_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748321_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748321_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748326.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748326_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748326_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748326_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748331.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748331_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748331_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748331_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748351.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748351_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748351_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748351_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748386.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748386_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748386_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748386_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748396.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748396_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748396_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748396_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748401.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748401_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748401_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748401_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748411.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748411_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748411_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748411_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748441.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748441_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748441_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748441_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748461.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748461_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748461_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748461_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748481.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748481_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748481_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748481_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748491.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748491_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748491_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748491_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748511.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748511_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748511_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748511_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748516.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748516_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748516_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748516_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748531.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748531_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748531_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748531_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748536.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748536_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748536_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748536_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748561.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748561_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748561_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748561_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748571.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748571_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748571_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748571_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748576.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748576_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748576_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748576_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748581.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748581_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748581_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748581_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748591.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748591_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748591_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748591_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748596.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748596_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748596_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748596_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748606.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748606_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748606_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748606_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748611.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748611_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748611_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748611_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748626.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748626_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748626_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748626_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74863.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74863_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74863_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74863_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748641.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748641_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748641_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748641_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748646.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748646_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748646_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748646_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748656.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748656_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748656_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748656_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748666.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748666_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748666_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748666_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748671.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748671_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748671_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748671_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748686.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748686_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748686_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748686_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748706.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748706_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748706_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748706_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748711.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748711_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748711_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748711_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748731.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748731_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748731_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748731_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748736.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748736_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748736_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748736_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748741.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748741_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748741_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748741_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748746.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748746_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748746_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748746_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748781.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748781_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748781_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748781_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748791.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748791_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748791_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748791_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748806.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748806_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748806_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748806_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748816.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748816_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748816_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748816_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748826.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748826_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748826_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748826_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748886.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748886_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748886_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/748886_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74909.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74909_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74909_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/74909_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749111.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749111_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749111_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749111_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749651.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749651_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749651_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749651_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749981.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749981_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749981_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/749981_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75007.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75007_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75007_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75007_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750121.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750121_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750121_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750121_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75028.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75028_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75028_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75028_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750411.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750411_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750411_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750411_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750711.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750711_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750711_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750711_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750911.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750911_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750911_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/750911_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75119.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75119_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75119_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75119_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751461.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751461_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751461_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751461_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751601.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751601_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751601_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/751601_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752091.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752091_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752091_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752091_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752101.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752101_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752101_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752101_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752566.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752566_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752566_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752566_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75272.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75272_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75272_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75272_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75277.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75277_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75277_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75277_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752916.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752916_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752916_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/752916_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75336.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75336_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75336_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75336_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75341.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75341_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75341_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75341_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753826.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753826_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753826_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753826_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753911.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753911_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753911_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753911_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753916.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753916_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753916_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/753916_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75473.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75473_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75473_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75473_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75503.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75503_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75503_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75503_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755051.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755051_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755051_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755051_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755346.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755346_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755346_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755346_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755471.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755471_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755471_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755471_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755481.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755481_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755481_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755481_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755721.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755721_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755721_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/755721_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756396.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756396_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756396_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756396_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75649.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75649_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75649_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75649_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75650.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75650_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75650_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75650_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756706.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756706_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756706_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756706_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756711.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756711_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756711_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/756711_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75672.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75672_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75672_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75672_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/7571.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757101.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757101_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757101_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757101_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757121.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757121_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757121_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/757121_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/7571_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/7571_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/7571_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75837.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75837_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75837_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/75837_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758511.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758511_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758511_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758511_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758901.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758901_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758901_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758901_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758911.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758911_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758911_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/758911_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759431.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759431_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759431_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759431_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759646.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759646_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759646_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759646_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759716.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759716_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759716_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759716_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759776.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759776_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759776_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759776_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759791.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759791_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759791_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759791_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759796.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759796_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759796_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759796_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759941.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759941_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759941_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/759941_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/76003.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/76003_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/76003_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/76003_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760206.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760206_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760206_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760206_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760511.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760511_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/760511_aug2_shift-1.mid
# ...
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980446.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980446_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980446_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980446_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980551.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980551_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980551_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980551_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98057.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98057_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98057_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98057_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98098.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98098_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98098_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98098_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/980_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98103.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98103_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98103_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98103_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98104.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98104_aug1_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98104_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98104_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98106.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98106_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98106_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98106_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98108.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98108_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98108_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98108_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98111.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981111.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981111_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981111_aug2_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981111_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98111_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98111_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98111_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981151.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981151_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981151_aug2_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981151_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98172.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98172_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98172_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98172_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98175.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98175_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98175_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98175_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/981_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98226.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98226_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98226_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98226_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/983.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/983_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/983_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/983_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98431.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98431_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98431_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98431_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98459.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98459_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98459_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98459_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98502.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98502_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98502_aug2_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98502_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98505.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98505_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98505_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98505_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/986.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98609.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98609_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98609_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98609_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9866.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98664.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98664_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98664_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98664_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9866_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9866_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9866_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98688.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98688_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98688_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98688_aug3_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98694.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98694_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98694_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98694_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98696.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98696_aug1_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98696_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98696_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/986_aug1_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/986_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/986_aug3_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/987.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98774.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98774_aug1_shift+1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98774_aug2_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98774_aug3_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/987_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/987_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/987_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/988.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/988_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/988_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/988_aug3_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98939.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98939_aug1_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98939_aug2_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/98939_aug3_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9896.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9896_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9896_aug2_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/9896_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99061.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99061_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99061_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99061_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99072.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99072_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99072_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99072_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99162.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99162_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99162_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99162_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99338.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99338_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99338_aug2_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99338_aug3_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99396.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99396_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99396_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99396_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/994.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/994_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/994_aug2_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/994_aug3_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/995.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99518.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99518_aug1_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99518_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99518_aug3_shift-7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/995_aug1_shift-6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/995_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/995_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99791.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99791_aug1_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99791_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99791_aug3_shift-1.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99796.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99796_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99796_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99796_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99884.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99884_aug1_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99884_aug2_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99884_aug3_shift+4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99901.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99901_aug1_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99901_aug2_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99901_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99963.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99963_aug1_shift-4.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99963_aug2_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/99963_aug3_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/bach_prelude_C.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/bach_prelude_C_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/bach_prelude_C_aug2_shift+6.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/bach_prelude_C_aug3_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/fur_elise.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/fur_elise_aug1_shift+3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/fur_elise_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/fur_elise_aug3_shift-2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/minuet_in_G.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/minuet_in_G_aug1_shift+7.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/minuet_in_G_aug2_shift-3.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/minuet_in_G_aug3_shift+5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/ode_to_joy.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/ode_to_joy_aug1_shift-5.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/ode_to_joy_aug2_shift+2.mid
#   inflating: /content/DATASET_AUGMENTED/DATASET_AUGMENTED/ode_to_joy_aug3_shift-4.mid

# %%
# !pip install -qq torch midi_neural_processor pretty_midi tqdm utils
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 90.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 115.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 5.1 MB/s eta 0:00:00
#   Building wheel for pretty_midi (setup.py) ... done
#   Building wheel for utils (setup.py) ... done

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.22.0-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.22.0 (from mlflow)
#   Downloading mlflow_skinny-2.22.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.6)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.8)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.2)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.15.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading databricks_sdk-0.52.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (1.16.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (1.16.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (5.29.4)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (2.11.4)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow) (4.13.2)
# Collecting uvicorn<1 (from mlflow-skinny==2.22.0->mlflow)
#   Downloading uvicorn-0.34.2-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow) (1.1.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (2.38.0)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.22.0->mlflow)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.2.18)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (75.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.37b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (0.37b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.22.0->mlflow) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.22.0->mlflow) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.11/dist-packages (from uvicorn<1->mlflow-skinny==2.22.0->mlflow) (0.16.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.22.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.11/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (4.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi<1->mlflow-skinny==2.22.0->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow) (0.6.1)
# Downloading mlflow-2.22.0-py3-none-any.whl (29.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 82.0 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.22.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 128.4 MB/s eta 0:00:00
# Downloading alembic-1.15.2-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 21.9 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 14.6 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 12.1 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 8.8 MB/s eta 0:00:00
# Downloading databricks_sdk-0.52.0-py3-none-any.whl (700 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.2/700.2 kB 49.7 MB/s eta 0:00:00
# Downloading fastapi-0.115.12-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 10.5 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 19.8 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading uvicorn-0.34.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 6.5 MB/s eta 0:00:00
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 8.0 MB/s eta 0:00:00
# Installing collected packages: uvicorn, gunicorn, graphql-core, starlette, graphql-relay, docker, alembic, graphene, fastapi, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed alembic-1.15.2 databricks-sdk-0.52.0 docker-7.1.0 fastapi-0.115.12 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.22.0 mlflow-skinny-2.22.0 starlette-0.46.2 uvicorn-0.34.2

# %%
import os
import random

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

from tqdm import tqdm
import mlflow

import midi_neural_processor.processor as midi_tokenizer

# %%
EVENT_RANGE = midi_tokenizer.RANGE_NOTE_ON
EVENT_RANGE += midi_tokenizer.RANGE_NOTE_OFF
EVENT_RANGE += midi_tokenizer.RANGE_TIME_SHIFT
EVENT_RANGE += midi_tokenizer.RANGE_VEL

CONFIG = {
    "max_sequence_len": 1024,
    "block_size": 512,
    "embedding_dim": 256,
    "num_heads": 8,
    "num_layers": 6,
    "batch_size": 16,
    "token_pad": EVENT_RANGE,
    "token_sos": EVENT_RANGE + 1,
    "token_eos": EVENT_RANGE + 2,
    "vocab_size": EVENT_RANGE + 3,
    "seed": 42,
    "model_out": "midi_transformer_model.pt"
}

# %%
DATASET_DIR = "/content/DATASET_AUGMENTED/DATASET_AUGMENTED"

all_midis = [f for f in os.listdir(DATASET_DIR) if f.endswith(".mid")]
random.shuffle(all_midis)

total_midis = len(all_midis)
midis_train = int(0.9 * total_midis)
midis_validation = int(0.1 * total_midis)

train_files = all_midis[:midis_train]
validation_files = all_midis[midis_train:]

# %%
print(len(train_files))
print(len(validation_files))
print(len(all_midis))
# Out:
# 31730
# 3526
# 35256

# %%
list_of_seqs = []
MAX_SEQ_LEN = CONFIG['max_sequence_len']
MAX_SEQ_LEN_MUSIC_ONLY = MAX_SEQ_LEN - 2

print(f"Encoding {total_midis} MIDI files into sequences.")

for f in tqdm(all_midis, desc="Encoding MIDI files into sequences"):
    tokens = midi_tokenizer.encode_midi(os.path.join(DATASET_DIR, f))

    for i in range(0, len(tokens), MAX_SEQ_LEN_MUSIC_ONLY):
        chunk = tokens[i : i + MAX_SEQ_LEN_MUSIC_ONLY]

        if len(chunk) < MAX_SEQ_LEN_MUSIC_ONLY:
            pad_count = MAX_SEQ_LEN_MUSIC_ONLY - len(chunk)
            chunk = chunk + [CONFIG['token_pad']] * pad_count

        seq = [CONFIG['token_sos']] + chunk + [CONFIG['token_eos']]
        assert len(seq) == MAX_SEQ_LEN

        list_of_seqs.append(seq)

print(f"Total token sequences: {len(list_of_seqs)}")
# Out:
# Encoding 35256 MIDI files into sequences.
# Encoding MIDI files into sequences:   4%|▍         | 1394/35256 [00:07<03:14, 174.54it/s]/usr/local/lib/python3.11/dist-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# Encoding MIDI files into sequences: 100%|██████████| 35256/35256 [03:35<00:00, 163.87it/s]
# Total token sequences: 47422

# %%
NUM_SEQUENCES = len(list_of_seqs)
print(NUM_SEQUENCES)

train_seqs = list_of_seqs[:int(0.9 * NUM_SEQUENCES)]
val_seqs = list_of_seqs[int(0.9 * NUM_SEQUENCES):]

print(len(train_seqs))
print(len(val_seqs))
# Out:
# 47422
# 42679
# 4743

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
train_data = torch.tensor(train_seqs, dtype=torch.long, device=DEVICE)
print(train_data.shape, train_data.dtype)
print(train_data[:100])

test_data = torch.tensor(val_seqs, dtype=torch.long, device=DEVICE)
print(test_data.shape, test_data.dtype)
print(test_data[:100])
# Out:
# torch.Size([42679, 1024]) torch.int64
# tensor([[389, 295, 376,  ..., 388, 388, 390],
#         [389, 355, 295,  ..., 198, 387, 390],
#         [389,  72, 264,  ..., 256, 387, 390],
#         ...,
#         [389, 271, 178,  ..., 388, 388, 390],
#         [389, 355, 355,  ..., 388, 388, 390],
#         [389, 295, 376,  ..., 388, 388, 390]], device='cuda:0')
# torch.Size([4743, 1024]) torch.int64
# tensor([[389, 315, 376,  ..., 388, 388, 390],
#         [389, 376,  60,  ..., 388, 388, 390],
#         [389, 376,  74,  ..., 376,  65, 390],
#         ...,
#         [389, 376,  67,  ..., 388, 388, 390],
#         [389, 267, 376,  ..., 388, 388, 390],
#         [389, 376,  54,  ..., 388, 388, 390]], device='cuda:0')

# %%
X_train = train_data[:, :-1]
Y_train = train_data[:, 1:]

X_val = test_data[:, :-1]
Y_val = test_data[:, 1:]

# %%
train_ds = TensorDataset(X_train, Y_train)
val_ds   = TensorDataset(X_val,   Y_val)

# %%
train_loader = DataLoader(
    train_ds,
    batch_size=CONFIG['batch_size'],
    shuffle=True,
    drop_last=True
)

val_loader = DataLoader(
    val_ds,
    batch_size=CONFIG['batch_size'],
    shuffle=False,
    drop_last=True
)

# %%
class Head(nn.Module):
    """
    Individual head responsible for applying the attention mechanism and
    relative positional embeddings.
    """

    def __init__(self, head_size, n_embd, block_size, dropout=0.1, relative_pos=True):
        """
        Initialize the AttentionHead.

        Args:
            head_size (int): The size of the attention head.
            embedding_dim (int): The input embedding dimension.
            block_size (int): The maximum sequence length supported.
            dropout (float, optional): Dropout probability. Defaults to 0.1.
            use_relative_position (bool, optional): Whether to apply relative positional embeddings.
        """

        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.dropout = nn.Dropout(dropout)
        self.block_size = block_size
        self.relative_pos = relative_pos

        if relative_pos:
            # relative_embeddings: [block_size, head_size]
            self.relative_embeddings = nn.Parameter(torch.randn(CONFIG['max_sequence_len'], head_size))
        else:
            self.relative_embeddings = None

    def _skew(self, x):
        """
        Apply skewing operation for relative positional attention.

        Args:
            attention_scores (torch.Tensor): The attention scores tensor of shape (batch_size, seq_len, seq_len).

        Returns:
            torch.Tensor: Skewed attention scores tensor.
        """

        B, T1, T2 = x.size()
        x = F.pad(x, (1, 0))              # (B, T, T+1)
        x = x.view(B, T2 + 1, T1)
        x = x[:, 1:, :]
        return x.transpose(1, 2)


    def forward(self, x):

        """
        Forward pass for computing attention outputs.

        Args:
            input_sequence (torch.Tensor): Input tensor of shape (batch_size, seq_len, embedding_dim).

        Returns:
            torch.Tensor: Output tensor of shape (batch_size, seq_len, head_size).
        """

        _, T, _ = x.shape
        k = self.key(x)
        q = self.query(x)
        v = self.value(x)

        # Compute attention scores
        att = q @ k.transpose(-2, -1) / (k.size(-1) ** 0.5)  # (B, T, T)

        if self.relative_pos:
            # (head_size, T)
            relative_embeddings_transposed = self.relative_embeddings[:T, :].transpose(0, 1)
            rel_att = q @ relative_embeddings_transposed  # (B, T, T)
            rel_att = self._skew(rel_att)  # Skew to match shape
            att = att + rel_att

        # Apply causal mask
        mask = torch.tril(torch.ones(T, T, device=x.device))
        att = att.masked_fill(mask == 0, float("-inf"))

        att = F.softmax(att, dim=-1)
        att = self.dropout(att)
        out = att @ v  # (B, T, head_size)
        return out

# %%
class MultiHeadAttention(nn.Module):
    """
    Multi-head attention mechanism with optional relative positional embeddings.

    Combines multiple independent attention heads and projects the result back to the
    original embedding space.
    """

    def __init__(self, num_heads, n_embd, block_size, dropout=0.1, relative_pos=True):
        """
        Initialize the MultiHeadAttention module.

        Args:
            num_heads (int): Number of attention heads.
            embedding_dim (int): Dimension of the input embeddings.
            block_size (int): Maximum sequence length supported.
            dropout (float, optional): Dropout probability. Defaults to 0.1.
            use_relative_position (bool, optional): Whether to apply relative positional embeddings. Defaults to True.
        """

        super().__init__()
        head_size = n_embd // num_heads
        self.heads = nn.ModuleList([
            Head(head_size, n_embd, block_size, dropout, relative_pos=relative_pos)
            for _ in range(num_heads)
        ])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        """
        Forward pass to compute multi-head attention outputs.

        Args:
            input_sequence (torch.Tensor): Input tensor of shape (batch_size, seq_len, embedding_dim).

        Returns:
            torch.Tensor: Output tensor of shape (batch_size, seq_len, embedding_dim).
        """
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        return self.dropout(self.proj(out))

# %%
class FeedForward(nn.Module):
    """
    Feed-forward neural network with activation and dropout.

    This is typically used as the second component of a Transformer block.
    """

    def __init__(self, n_embd, dropout=0.1):
        """
        Initialize the FeedForward module.

        Args:
            embedding_dim (int): Dimension of the input and output embeddings.
            dropout (float, optional): Dropout probability. Defaults to 0.1.
        """
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        """
        Forward pass through the feed-forward network.

        Args:
            input_sequence (torch.Tensor): Input tensor of shape (batch_size, seq_len, embedding_dim).

        Returns:
            torch.Tensor: Output tensor of the same shape.
        """
        return self.net(x)


class Block(nn.Module):
    """
    Single Transformer block consisting of multi-head attention,
    feed-forward network, and layer normalization.
    """

    def __init__(self, n_embd, n_head, block_size, dropout=0.1):
        """
        Initialize the TransformerBlock.

        Args:
            embedding_dim (int): Dimension of the input embeddings.
            num_heads (int): Number of attention heads.
            block_size (int): Maximum sequence length.
            dropout (float, optional): Dropout probability. Defaults to 0.1.
        """
        super().__init__()
        self.sa = MultiHeadAttention(n_head, n_embd, block_size, dropout)
        self.ffwd = FeedForward(n_embd, dropout)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        """
        Forward pass through the Transformer block.

        Args:
            input_sequence (torch.Tensor): Input tensor of shape (batch_size, seq_len, embedding_dim).

        Returns:
            torch.Tensor: Output tensor of the same shape.
        """
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# %%
"""Model class, processes input and target token sequences through
stacked transformer decoder blocks"""

class TransformerMIDILanguageModel(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.block_size    = config['block_size']
        self.vocab_size    = config['vocab_size']
        self.sos_token_id  = config['token_sos']
        self.pad_token_id  = config['token_pad']
        self.eos_token_id  = config['token_eos']

        self.token_embedding_table = nn.Embedding(
            self.vocab_size,
            config['embedding_dim'],
            padding_idx=self.pad_token_id
        )

        self.blocks = nn.Sequential(*[
            Block(n_embd=config['embedding_dim'],
                  n_head=config['num_heads'],
                  block_size=config['block_size'],
                  dropout=0.1)
            for _ in range(config['num_layers'])
            ])

        self.ln_f = nn.LayerNorm(config['embedding_dim'])
        self.lm_head = nn.Linear(config['embedding_dim'], self.vocab_size)


    def forward(self, idx, targets=None):
        tok_emb = self.token_embedding_table(idx)

        x = self.blocks(tok_emb)
        x = self.ln_f(x)

        logits = self.lm_head(x)

        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.vocab_size), targets.view(-1),
                                   ignore_index=self.pad_token_id)
        return logits, loss

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, eos_token_id, temperature=1.0, top_k=None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -self.block_size:]
            logits, _ = self(idx_cond)

            logits = logits[:, -1, :] / temperature

            if top_k is not None:
                v, _ = torch.topk(logits, top_k, dim=-1)
                min_vals = v[:, -1].unsqueeze(1)
                logits[logits < min_vals] = -float('Inf')

            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat([idx, idx_next], dim=1)

            if eos_token_id is not None:
                # check every item in batch
                eos_mask = idx_next.eq(eos_token_id).view(-1)
                if eos_mask.all():
                    break

        return idx

# %%
model = TransformerMIDILanguageModel(CONFIG).to(DEVICE)
print(sum(p.numel() for p in model.parameters()) / 1e6, "M parameters")
print(model)
# Out:
# 6.507911 M parameters
# TransformerMIDILanguageModel(
#   (token_embedding_table): Embedding(391, 256, padding_idx=388)
#   (blocks): Sequential(
#     (0): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (4): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (ln_f): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (lm_head): Linear(in_features=256, out_features=391, bias=True)
# )

# %%
@torch.no_grad()
def estimate_loss(model, val_loader, eval_iters, device):
    model.eval()
    losses = []
    for i, (xb, yb) in enumerate(val_loader):
        if i >= eval_iters:
            break
        xb, yb = xb.to(device), yb.to(device)
        _, loss = model(xb, yb)
        losses.append(loss.item())
    model.train()
    return sum(losses) / len(losses)

# %%
def train_model(
    model,
    train_loader,
    val_loader,
    optimizer,
    config,
    device,
    max_epochs=50,
    eval_iters=200,
    experiment_name="MIDI_Transformer_Exp",
    run_name=None,
    start_epoch=0
):

    patience = 7

    mlflow.set_experiment(experiment_name)
    with mlflow.start_run(run_name=run_name):
        # Log all config parameters
        for k, v in config.items():
            mlflow.log_param(k, v)

        mlflow.log_param("optimizer", "AdamW")
        mlflow.log_param("learning_rate", optimizer.param_groups[0]['lr'])

        best_val_loss = float("inf")
        train_loss_log = []
        val_loss_log = []
        early_stop_counter = 0

        for epoch in range(start_epoch, start_epoch + max_epochs):
            model.train()
            running_loss = 0.0
            pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{start_epoch + max_epochs}")

            for xb, yb in pbar:
                xb, yb = xb.to(device), yb.to(device)
                optimizer.zero_grad(set_to_none=True)
                _, loss = model(xb, yb)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                pbar.set_postfix(train_loss=running_loss / (pbar.n + 1))

            avg_train_loss = running_loss / len(train_loader)
            train_loss_log.append(avg_train_loss)
            mlflow.log_metric("train_loss", avg_train_loss, step=epoch)

            # Evaluate on val set
            avg_val_loss = estimate_loss(model, val_loader, eval_iters, device)
            val_loss_log.append(avg_val_loss)
            mlflow.log_metric("val_loss", avg_val_loss, step=epoch)

            print(
                f"Epoch {epoch+1}: train loss = {avg_train_loss:.4f}, val loss = {avg_val_loss:.4f}"
                )

            # Save best model
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_path = f"best_model_{epoch}.pth"
                torch.save(model.state_dict(), best_model_path)
                mlflow.log_artifact(best_model_path)
                print(f"Best model saved at epoch {epoch+1} with val loss {best_val_loss:.4f}")

                best_optimizer_path = f"best_optimizer_{epoch+1}.pth"
                torch.save(optimizer.state_dict(), best_optimizer_path)
                mlflow.log_artifact(best_optimizer_path)
            else:
                early_stop_counter += 1
                print(f"No improvement for {early_stop_counter} epoch.")

            if early_stop_counter >= patience:
                print(f"Early stopping at epoch {epoch+1}.")
                break

        return model, train_loss_log, val_loss_log

# %%
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)

trained_model, train_log, val_log = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    config=CONFIG,
    device=DEVICE,
    max_epochs=50,
    eval_iters=200,
    experiment_name="MIDI_Transformer_Training",
    run_name="Run_01"
)
# Out:
# Epoch 1/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.919]
# Epoch 1: train loss = 0.9186, val loss = 0.8663
# Best model saved at epoch 1 with val loss 0.8663
# Epoch 2/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.866]
# Epoch 2: train loss = 0.8659, val loss = 0.8345
# Best model saved at epoch 2 with val loss 0.8345
# Epoch 3/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.835]
# Epoch 3: train loss = 0.8345, val loss = 0.8044
# Best model saved at epoch 3 with val loss 0.8044
# Epoch 4/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.804]
# Epoch 4: train loss = 0.8039, val loss = 0.7756
# Best model saved at epoch 4 with val loss 0.7756
# Epoch 5/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.778]
# Epoch 5: train loss = 0.7777, val loss = 0.7529
# Best model saved at epoch 5 with val loss 0.7529
# Epoch 6/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.757]
# Epoch 6: train loss = 0.7565, val loss = 0.7343
# Best model saved at epoch 6 with val loss 0.7343
# Epoch 7/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.739]
# Epoch 7: train loss = 0.7390, val loss = 0.7204
# Best model saved at epoch 7 with val loss 0.7204
# Epoch 8/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.725]
# Epoch 8: train loss = 0.7246, val loss = 0.7102
# Best model saved at epoch 8 with val loss 0.7102
# Epoch 9/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.712]
# Epoch 9: train loss = 0.7122, val loss = 0.7000
# Best model saved at epoch 9 with val loss 0.7000
# Epoch 10/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.701]
# Epoch 10: train loss = 0.7010, val loss = 0.6890
# Best model saved at epoch 10 with val loss 0.6890
# Epoch 11/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.668]
# Epoch 11: train loss = 0.6677, val loss = 0.6193
# Best model saved at epoch 11 with val loss 0.6193
# Epoch 12/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.63]
# Epoch 12: train loss = 0.6302, val loss = 0.5947
# Best model saved at epoch 12 with val loss 0.5947
# Epoch 13/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.608]
# Epoch 13: train loss = 0.6084, val loss = 0.5793
# Best model saved at epoch 13 with val loss 0.5793
# Epoch 14/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.593]
# Epoch 14: train loss = 0.5931, val loss = 0.5708
# Best model saved at epoch 14 with val loss 0.5708
# Epoch 15/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.582]
# Epoch 15: train loss = 0.5819, val loss = 0.5638
# Best model saved at epoch 15 with val loss 0.5638
# Epoch 16/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.574]
# Epoch 16: train loss = 0.5739, val loss = 0.5584
# Best model saved at epoch 16 with val loss 0.5584
# Epoch 17/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.566]
# Epoch 17: train loss = 0.5662, val loss = 0.5560
# Best model saved at epoch 17 with val loss 0.5560
# Epoch 18/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.56]
# Epoch 18: train loss = 0.5595, val loss = 0.5478
# Best model saved at epoch 18 with val loss 0.5478
# Epoch 19/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.553]
# Epoch 19: train loss = 0.5534, val loss = 0.5430
# Best model saved at epoch 19 with val loss 0.5430
# Epoch 20/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.548]
# Epoch 20: train loss = 0.5482, val loss = 0.5391
# Best model saved at epoch 20 with val loss 0.5391
# Epoch 21/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.542]
# Epoch 21: train loss = 0.5425, val loss = 0.5380
# Best model saved at epoch 21 with val loss 0.5380
# Epoch 22/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.538]
# Epoch 22: train loss = 0.5380, val loss = 0.5331
# Best model saved at epoch 22 with val loss 0.5331
# Epoch 23/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.533]
# Epoch 23: train loss = 0.5331, val loss = 0.5293
# Best model saved at epoch 23 with val loss 0.5293
# Epoch 24/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.529]
# Epoch 24: train loss = 0.5289, val loss = 0.5247
# Best model saved at epoch 24 with val loss 0.5247
# Epoch 25/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.525]
# Epoch 25: train loss = 0.5246, val loss = 0.5228
# Best model saved at epoch 25 with val loss 0.5228
# Epoch 26/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.521]
# Epoch 26: train loss = 0.5208, val loss = 0.5187
# Best model saved at epoch 26 with val loss 0.5187
# Epoch 27/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.517]
# Epoch 27: train loss = 0.5171, val loss = 0.5165
# Best model saved at epoch 27 with val loss 0.5165
# Epoch 28/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.514]
# Epoch 28: train loss = 0.5137, val loss = 0.5151
# Best model saved at epoch 28 with val loss 0.5151
# Epoch 29/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.51]
# Epoch 29: train loss = 0.5102, val loss = 0.5112
# Best model saved at epoch 29 with val loss 0.5112
# Epoch 30/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.507]
# Epoch 30: train loss = 0.5071, val loss = 0.5101
# Best model saved at epoch 30 with val loss 0.5101
# Epoch 31/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.504]
# Epoch 31: train loss = 0.5040, val loss = 0.5074
# Best model saved at epoch 31 with val loss 0.5074
# Epoch 32/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.501]
# Epoch 32: train loss = 0.5014, val loss = 0.5051
# Best model saved at epoch 32 with val loss 0.5051
# Epoch 33/50: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.498]
# Epoch 33: train loss = 0.4983, val loss = 0.5036
# Best model saved at epoch 33 with val loss 0.5036
# Epoch 34/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.496]
# Epoch 34: train loss = 0.4959, val loss = 0.5037
# No improvement for 1 epoch.
# Epoch 35/50: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.493]
# Epoch 35: train loss = 0.4930, val loss = 0.5001
# Best model saved at epoch 35 with val loss 0.5001
# Epoch 36/50:  83%|████████▎ | 2223/2667 [09:33<01:54,  3.88it/s, train_loss=0.49]

# %% [markdown]
# Additional training on 50 epochs model

# %%
model_trained_on_50_epochs = TransformerMIDILanguageModel(CONFIG).to(DEVICE)
model_trained_on_50_epochs.load_state_dict(torch.load("best_model_49.pth"))
model_trained_on_50_epochs.eval()
optimizer_additional_50_epochs = torch.optim.Adam(model_trained_on_50_epochs.parameters(), lr=1e-4)
print(model_trained_on_50_epochs)
# Out:
# TransformerMIDILanguageModel(
#   (token_embedding_table): Embedding(391, 256, padding_idx=388)
#   (blocks): Sequential(
#     (0): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (4): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-7): 8 x Head(
#             (key): Linear(in_features=256, out_features=32, bias=False)
#             (query): Linear(in_features=256, out_features=32, bias=False)
#             (value): Linear(in_features=256, out_features=32, bias=False)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=256, out_features=256, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (ffwd): FeedForward(
#         (net): Sequential(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Linear(in_features=1024, out_features=256, bias=True)
#           (3): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (ln_f): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (lm_head): Linear(in_features=256, out_features=391, bias=True)
# )

# %%
trained_model, train_log, val_log = train_model(
    model=model_trained_on_50_epochs,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer_additional_50_epochs,
    config=CONFIG,
    device=DEVICE,
    max_epochs=100,
    eval_iters=200,
    experiment_name="MIDI_Transformer_Training",
    run_name="Run_Resume",
    start_epoch=50
)
# Out:
# 2025/05/10 21:15:32 INFO mlflow.tracking.fluent: Experiment with name 'MIDI_Transformer_Training' does not exist. Creating a new experiment.
# Epoch 51/150: 100%|██████████| 2667/2667 [11:29<00:00,  3.87it/s, train_loss=1.37]
# Epoch 51: train loss = 1.3693, val loss = 0.9553
# Best model saved at epoch 51 with val loss 0.9553
# Epoch 52/150: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.916]
# Epoch 52: train loss = 0.9158, val loss = 0.8827
# Best model saved at epoch 52 with val loss 0.8827
# Epoch 53/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.865]
# Epoch 53: train loss = 0.8647, val loss = 0.8518
# Best model saved at epoch 53 with val loss 0.8518
# Epoch 54/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.834]
# Epoch 54: train loss = 0.8340, val loss = 0.8231
# Best model saved at epoch 54 with val loss 0.8231
# Epoch 55/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.804]
# Epoch 55: train loss = 0.8038, val loss = 0.7943
# Best model saved at epoch 55 with val loss 0.7943
# Epoch 56/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.778]
# Epoch 56: train loss = 0.7775, val loss = 0.7695
# Best model saved at epoch 56 with val loss 0.7695
# Epoch 57/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.757]
# Epoch 57: train loss = 0.7570, val loss = 0.7501
# Best model saved at epoch 57 with val loss 0.7501
# Epoch 58/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.739]
# Epoch 58: train loss = 0.7391, val loss = 0.7357
# Best model saved at epoch 58 with val loss 0.7357
# Epoch 59/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.723]
# Epoch 59: train loss = 0.7233, val loss = 0.7207
# Best model saved at epoch 59 with val loss 0.7207
# Epoch 60/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.702]
# Epoch 60: train loss = 0.7015, val loss = 0.6716
# Best model saved at epoch 60 with val loss 0.6716
# Epoch 61/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.657]
# Epoch 61: train loss = 0.6569, val loss = 0.6288
# Best model saved at epoch 61 with val loss 0.6288
# Epoch 62/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.628]
# Epoch 62: train loss = 0.6275, val loss = 0.6086
# Best model saved at epoch 62 with val loss 0.6086
# Epoch 63/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.609]
# Epoch 63: train loss = 0.6089, val loss = 0.5958
# Best model saved at epoch 63 with val loss 0.5958
# Epoch 64/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.595]
# Epoch 64: train loss = 0.5949, val loss = 0.5863
# Best model saved at epoch 64 with val loss 0.5863
# Epoch 65/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.584]
# Epoch 65: train loss = 0.5839, val loss = 0.5815
# Best model saved at epoch 65 with val loss 0.5815
# Epoch 66/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.575]
# Epoch 66: train loss = 0.5750, val loss = 0.5742
# Best model saved at epoch 66 with val loss 0.5742
# Epoch 67/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.568]
# Epoch 67: train loss = 0.5677, val loss = 0.5679
# Best model saved at epoch 67 with val loss 0.5679
# Epoch 68/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.561]
# Epoch 68: train loss = 0.5609, val loss = 0.5646
# Best model saved at epoch 68 with val loss 0.5646
# Epoch 69/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.555]
# Epoch 69: train loss = 0.5548, val loss = 0.5589
# Best model saved at epoch 69 with val loss 0.5589
# Epoch 70/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.549]
# Epoch 70: train loss = 0.5492, val loss = 0.5561
# Best model saved at epoch 70 with val loss 0.5561
# Epoch 71/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.544]
# Epoch 71: train loss = 0.5440, val loss = 0.5526
# Best model saved at epoch 71 with val loss 0.5526
# Epoch 72/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.539]
# Epoch 72: train loss = 0.5390, val loss = 0.5493
# Best model saved at epoch 72 with val loss 0.5493
# Epoch 73/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.535]
# Epoch 73: train loss = 0.5346, val loss = 0.5466
# Best model saved at epoch 73 with val loss 0.5466
# Epoch 74/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.531]
# Epoch 74: train loss = 0.5311, val loss = 0.5437
# Best model saved at epoch 74 with val loss 0.5437
# Epoch 75/150: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.527]
# Epoch 75: train loss = 0.5270, val loss = 0.5405
# Best model saved at epoch 75 with val loss 0.5405
# Epoch 76/150: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.523]
# Epoch 76: train loss = 0.5230, val loss = 0.5384
# Best model saved at epoch 76 with val loss 0.5384
# Epoch 77/150: 100%|██████████| 2667/2667 [11:27<00:00,  3.88it/s, train_loss=0.52]
# Epoch 77: train loss = 0.5198, val loss = 0.5363
# Best model saved at epoch 77 with val loss 0.5363
# Epoch 78/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.516]
# Epoch 78: train loss = 0.5164, val loss = 0.5353
# Best model saved at epoch 78 with val loss 0.5353
# Epoch 79/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.514]
# Epoch 79: train loss = 0.5135, val loss = 0.5324
# Best model saved at epoch 79 with val loss 0.5324
# Epoch 80/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.51]
# Epoch 80: train loss = 0.5101, val loss = 0.5293
# Best model saved at epoch 80 with val loss 0.5293
# Epoch 81/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.507]
# Epoch 81: train loss = 0.5070, val loss = 0.5290
# Best model saved at epoch 81 with val loss 0.5290
# Epoch 82/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.505]
# Epoch 82: train loss = 0.5046, val loss = 0.5242
# Best model saved at epoch 82 with val loss 0.5242
# Epoch 83/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.502]
# Epoch 83: train loss = 0.5016, val loss = 0.5238
# Best model saved at epoch 83 with val loss 0.5238
# Epoch 84/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.499]
# Epoch 84: train loss = 0.4992, val loss = 0.5217
# Best model saved at epoch 84 with val loss 0.5217
# Epoch 85/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.497]
# Epoch 85: train loss = 0.4967, val loss = 0.5203
# Best model saved at epoch 85 with val loss 0.5203
# Epoch 86/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.494]
# Epoch 86: train loss = 0.4940, val loss = 0.5187
# Best model saved at epoch 86 with val loss 0.5187
# Epoch 87/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.492]
# Epoch 87: train loss = 0.4918, val loss = 0.5178
# Best model saved at epoch 87 with val loss 0.5178
# Epoch 88/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.49]
# Epoch 88: train loss = 0.4898, val loss = 0.5151
# Best model saved at epoch 88 with val loss 0.5151
# Epoch 89/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.488]
# Epoch 89: train loss = 0.4876, val loss = 0.5149
# Best model saved at epoch 89 with val loss 0.5149
# Epoch 90/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.486]
# Epoch 90: train loss = 0.4858, val loss = 0.5137
# Best model saved at epoch 90 with val loss 0.5137
# Epoch 91/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.483]
# Epoch 91: train loss = 0.4834, val loss = 0.5110
# Best model saved at epoch 91 with val loss 0.5110
# Epoch 92/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.88it/s, train_loss=0.481]
# Epoch 92: train loss = 0.4812, val loss = 0.5126
# No improvement for 1 epoch.
# Epoch 93/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.479]
# Epoch 93: train loss = 0.4795, val loss = 0.5098
# Best model saved at epoch 93 with val loss 0.5098
# Epoch 94/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.478]
# Epoch 94: train loss = 0.4778, val loss = 0.5078
# Best model saved at epoch 94 with val loss 0.5078
# Epoch 95/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.476]
# Epoch 95: train loss = 0.4763, val loss = 0.5077
# Best model saved at epoch 95 with val loss 0.5077
# Epoch 96/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.474]
# Epoch 96: train loss = 0.4739, val loss = 0.5066
# Best model saved at epoch 96 with val loss 0.5066
# Epoch 97/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.472]
# Epoch 97: train loss = 0.4723, val loss = 0.5062
# Best model saved at epoch 97 with val loss 0.5062
# Epoch 98/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.471]
# Epoch 98: train loss = 0.4710, val loss = 0.5055
# Best model saved at epoch 98 with val loss 0.5055
# Epoch 99/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.469]
# Epoch 99: train loss = 0.4693, val loss = 0.5058
# No improvement for 2 epoch.
# Epoch 100/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.468]
# Epoch 100: train loss = 0.4676, val loss = 0.5040
# Best model saved at epoch 100 with val loss 0.5040
# Epoch 101/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.466]
# Epoch 101: train loss = 0.4664, val loss = 0.5022
# Best model saved at epoch 101 with val loss 0.5022
# Epoch 102/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.465]
# Epoch 102: train loss = 0.4647, val loss = 0.5009
# Best model saved at epoch 102 with val loss 0.5009
# Epoch 103/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.463]
# Epoch 103: train loss = 0.4628, val loss = 0.5005
# Best model saved at epoch 103 with val loss 0.5005
# Epoch 104/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.462]
# Epoch 104: train loss = 0.4618, val loss = 0.5005
# Best model saved at epoch 104 with val loss 0.5005
# Epoch 105/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.46]
# Epoch 105: train loss = 0.4601, val loss = 0.4995
# Best model saved at epoch 105 with val loss 0.4995
# Epoch 106/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.459]
# Epoch 106: train loss = 0.4590, val loss = 0.4999
# No improvement for 3 epoch.
# Epoch 107/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.457]
# Epoch 107: train loss = 0.4574, val loss = 0.4985
# Best model saved at epoch 107 with val loss 0.4985
# Epoch 108/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.456]
# Epoch 108: train loss = 0.4564, val loss = 0.4984
# Best model saved at epoch 108 with val loss 0.4984
# Epoch 109/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.455]
# Epoch 109: train loss = 0.4549, val loss = 0.4973
# Best model saved at epoch 109 with val loss 0.4973
# Epoch 110/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.454]
# Epoch 110: train loss = 0.4538, val loss = 0.4948
# Best model saved at epoch 110 with val loss 0.4948
# Epoch 111/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.452]
# Epoch 111: train loss = 0.4523, val loss = 0.4965
# No improvement for 4 epoch.
# Epoch 112/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.451]
# Epoch 112: train loss = 0.4514, val loss = 0.4945
# Best model saved at epoch 112 with val loss 0.4945
# Epoch 113/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.45]
# Epoch 113: train loss = 0.4503, val loss = 0.4950
# No improvement for 5 epoch.
# Epoch 114/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.449]
# Epoch 114: train loss = 0.4493, val loss = 0.4931
# Best model saved at epoch 114 with val loss 0.4931
# Epoch 115/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.448]
# Epoch 115: train loss = 0.4479, val loss = 0.4924
# Best model saved at epoch 115 with val loss 0.4924
# Epoch 116/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.447]
# Epoch 116: train loss = 0.4468, val loss = 0.4909
# Best model saved at epoch 116 with val loss 0.4909
# Epoch 117/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.446]
# Epoch 117: train loss = 0.4459, val loss = 0.4921
# No improvement for 6 epoch.
# Epoch 118/150: 100%|██████████| 2667/2667 [11:28<00:00,  3.87it/s, train_loss=0.445]
# Epoch 118: train loss = 0.4446, val loss = 0.4915
# No improvement for 7 epoch.
# Early stopping at epoch 118.
