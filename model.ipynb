# %%
!7z x Dataset.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1345976 bytes (1315 KiB)
#
# Extracting archive: Dataset.7z
# --
# Path = Dataset.7z
# Type = 7z
# Physical Size = 1345976
# Headers Size = 41547
# Method = LZMA2:12m
# Solid = +
# Blocks = 1
#
# Everything is Ok
#
# Folders: 1
# Files: 4070
# Size:       9706090
# Compressed: 1345976

# %%
# !pip install miditoolkit mido pandas seaborn matplotlib
# Out:
# Collecting miditoolkit
#   Downloading miditoolkit-1.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting mido
#   Downloading mido-1.3.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.11/dist-packages (from miditoolkit) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading miditoolkit-1.0.1-py3-none-any.whl (24 kB)
# Downloading mido-1.3.3-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: mido, miditoolkit
# Successfully installed miditoolkit-1.0.1 mido-1.3.3

# %%
import miditoolkit
from mido import MidiFile, MidiTrack, MetaMessage, Message
import os
import pandas as pd
import json
import numpy as np
from pathlib import Path
import torch

# %%
def extract_note_attributes(note):
    duration = max(60, round((note.end - note.start) / 60) * 60)
    return (note.pitch, note.start, duration)


def insert_silence_tokens(note_events):
    result = []
    prev_end = None

    for pitch, start, duration in note_events:
        if prev_end is not None and start > prev_end:
            silence_duration = max(60, round((start - prev_end) / 60) * 60)
            result.append((0, silence_duration))

        result.append((pitch, duration))
        prev_end = start + duration

    return result


def extract_metadata(filename):
    midi = MidiFile(filename)
    metadata = {
        'ticks_per_beat': midi.ticks_per_beat,
        'time_signature': MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8),
        'key_signature': MetaMessage('key_signature', key='C'),
        'set_tempo': MetaMessage('set_tempo', tempo=500000)  # Default 120 BPM
    }

    for track in midi.tracks:
        for msg in track:
            if msg.type in metadata:
                metadata[msg.type] = msg

    return metadata


def encode_midi(filename):
    midi = miditoolkit.MidiFile(filename)
    note_events = [
        extract_note_attributes(note)
        for instrument in midi.instruments
        for note in instrument.notes
    ]

    tokens = insert_silence_tokens(note_events)
    return tokens


def tokens_to_ids(tokens, token_dict):
    return [token_dict[token] for token in tokens]


def ids_to_tokens(ids, id_to_token):
    return [id_to_token[_id] for _id in ids]


def decode_midi(notes, output_filename, metadata):
    mid = MidiFile(ticks_per_beat=metadata['ticks_per_beat'])
    track = MidiTrack()
    mid.tracks.append(track)

    # Add metadata and instrument info
    track.extend([
        metadata['time_signature'],
        metadata['key_signature'],
        metadata['set_tempo'],
        Message('program_change', channel=0, program=1, time=0),  # Instrument
        Message('control_change', channel=0, control=7, value=80, time=0)  # Volume
    ])

    current_time = 0
    for pitch, duration in notes:

        if pitch == 0:
            current_time += duration
        else:
            track.append(Message('note_on', note=pitch, velocity=100, time=current_time))
            track.append(Message('note_on', note=pitch, velocity=0, time=duration))
            current_time = 0

    mid.save(output_filename)


def decode_ids_to_midi(id_sequence, output_filename, metadata, id_to_token):
    tokens = ids_to_tokens(id_sequence, id_to_token)
    decode_midi(tokens, output_filename, metadata)

# %%
DATASET_DIR = "/content/Dataset"
all_tokens = []
token_set = set()

for filename in os.listdir(DATASET_DIR):
    if filename.lower().endswith('.mid'):
        filepath = os.path.join(DATASET_DIR, filename)
        tokens = encode_midi(filepath)

        all_tokens.extend(tokens)
        token_set.update(tokens)

        print(f"Encoded {filename}")
# Out:
# Encoded 12-do_what_you_can_track_2.mid
# Encoded 7-triumphavi_track_3.mid
# Encoded micor-fantasia19-a4_track_1.mid
# Encoded brewert-03-almaine_track_3.mid
# Encoded jenkinsj-fantasia8-a5_track_2.mid
# Encoded tomkinst-pavan4-a5_track_3.mid
# Encoded twv41-d4_track_1.mid
# Encoded ferraboscoa-fantasia08-a6_track_5.mid
# Encoded qv3.26_track_2.mid
# Encoded micor-fantasia11-a4_track_4.mid
# Encoded carwardenj-suite5-31-a_daunce_track_1.mid
# Encoded twv42-c2_track_4.mid
# Encoded twv54-b2_1_track_4.mid
# Encoded gibbonso-fantasia1-a6_track_1.mid
# Encoded 53_last_will_and_test_track_1.mid
# Encoded 10_galliard_track_5.mid
# Encoded twv42c1_track_1.mid
# Encoded 27_the_image_of_melan_track_4.mid
# Encoded tomkinst-fantasia06-a3_track_2.mid
# Encoded 6-follow_me_track_2.mid
# Encoded hingestonj-almande5-a3_track_3.mid
# Encoded triosonataop2nr6_1_track_2.mid
# Encoded twv52-a2_track_5.mid
# Encoded twv52-f1_track_1.mid
# Encoded canzon199_track_7.mid
# Encoded 13-terpsicore_track_3.mid
# Encoded naudot-suite6_track_1.mid
# Encoded micor-pavan1-a5_track_4.mid
# Encoded 12_galliard_track_2.mid
# Encoded brandenburg4-andante_track_5.mid
# Encoded coprarioj-fantasia49-a5_track_1.mid
# Encoded lawesw-108-cminor-fantasia_track_1.mid
# Encoded 34_muy_linda_track_5.mid
# Encoded jeffreysg-fantasia2-a3_track_2.mid
# Encoded eastm-fancy06_track_4.mid
# Encoded coprarioj-fantasia10-a3_track_2.mid
# Encoded tomkinst-pavan8-a5_track_2.mid
# Encoded coleman-vdgs007-corant_1_track_1.mid
# Encoded morley_la_sampogna_track_2.mid
# Encoded coprarioj-fantasia14-a5_track_5.mid
# Encoded twv40-142_4_track_1.mid
# Encoded jenkinsj-fantasia3-a5_track_2.mid
# Encoded fantaziaz739_1_track_2.mid
# Encoded mancini-sonata3_track_2.mid
# Encoded 08_semper_dowland_track_1.mid
# Encoded lupot-fantasia04-a6_track_6.mid
# Encoded hingestonj-almande4-a4_track_3.mid
# Encoded peersonm-almaine2_track_4.mid
# Encoded hingestonj-almande3-a3_track_3.mid
# Encoded croft-op3-no6_track_1.mid
# Encoded micor-fantasia4-a5_track_2.mid
# Encoded deeringr-fantasia4-a5_track_3.mid
# Encoded 05-la_avogadra_track_1.mid
# Encoded twv42c2maj_track_3.mid
# Encoded wardj-fantasia1-a5_track_2.mid
# Encoded canzonseconda_track_2.mid
# Encoded whitew-fantasisa2-a5_track_1.mid
# Encoded brewert-19-corant_track_4.mid
# Encoded weelkest-pavan1_track_4.mid
# Encoded tomkinst-fantasia17-a3_track_2.mid
# Encoded hingestonj-suite3-a6_track_5.mid
# Encoded hiltonj-fantasia4-a3_track_3.mid
# Encoded tomkinst-fantasia10-a3_track_1.mid
# Encoded jenkinsj-fantasia07-a6_track_2.mid
# Encoded ferraboscoa-fantasia01-a6_track_4.mid
# Encoded lupot-fantasia8-a4_track_1.mid
# Encoded lupot-fantasia10-a6_track_1.mid
# Encoded coleman-vdgs010-corant_1_track_3.mid
# Encoded coleman-vdgs201-aire_track_2.mid
# Encoded 13_john_souch_his_galiard_track_1.mid
# Encoded bassanog-fantasia11-a3_track_1.mid
# Encoded coprarioj-fantasia23-a5_track_3.mid
# Encoded blavetm-sonate_2_cmin_track_1.mid
# Encoded byrdw-fantasia3-a6_track_5.mid
# Encoded twv42-a4_track_2.mid
# Encoded gibbonso-fantasia2-a6_track_5.mid
# Encoded triosonataop2nr2_1_track_3.mid
# Encoded twv55-a2_track_1.mid
# Encoded 52_galliard_track_1.mid
# Encoded lawesw-set6-gminor_track_5.mid
# Encoded whitew-fantasisa1-a6_track_3.mid
# Encoded eastm-fancy11_track_1.mid
# Encoded bassanog-fantasia01-a3_track_1.mid
# Encoded ferraboscoa-fantasia01-a6_track_6.mid
# Encoded canzondecima_track_2.mid
# Encoded weelkest-fantasia-a6_track_1.mid
# Encoded canzon188_track_3.mid
# Encoded canzondecimaquarta_track_4.mid
# Encoded 17-polyhymnia_track_3.mid
# Encoded peersonm-almaine1_track_3.mid
# Encoded coprarioj-fantasia48-a5_track_2.mid
# Encoded 46_galliard_track_3.mid
# Encoded lupot-fantasia4-a4_track_4.mid
# Encoded coprarioj-fantasia20-a5_track_4.mid
# Encoded 44_nec_invideo_track_4.mid
# Encoded jenkinsj-fantasia6-a4_track_3.mid
# Encoded martini-plaisir-damour_track_2.mid
# Encoded coleman-vdgs211-almaine_track_3.mid
# Encoded hingestonj-fantasia1-a4_track_3.mid
# Encoded cranfordw-fantasia3-a4_track_2.mid
# Encoded lupot-fantasia09-a6_track_4.mid
# Encoded coprarioj-fantasia16-a5_track_2.mid
# Encoded jenkinsj-fantasia16-a4_track_2.mid
# Encoded jeffreysg-fantasia6-a3_track_3.mid
# Encoded jenkinsj-fantasia6-a4_track_1.mid
# Encoded hingestonj-almande8-a3_track_3.mid
# Encoded 29_mens_innovata_track_4.mid
# Encoded jenkinsj-pavin2-a6_track_1.mid
# Encoded lockem-suite4_track_4.mid
# Encoded gibbonso-fantasia3-a6_track_3.mid
# Encoded jenkinsj-fantasia06-a6_track_6.mid
# Encoded 10-la_porta_track_2.mid
# Encoded 15-calliope_track_3.mid
# Encoded 16_galliard_track_2.mid
# Encoded byrdw-fantasia1-a3_track_2.mid
# Encoded jenkinsj-fantasia8-a5_track_5.mid
# Encoded colemanc-fantasia3-a6_track_5.mid
# Encoded twv42-c2_track_1.mid
# Encoded 13-la_barbisona_track_2.mid
# Encoded micor-pavan4-a4_track_1.mid
# Encoded gibbonso-fantasia4-a6_track_5.mid
# Encoded micor-fantasia6-a3_track_3.mid
# Encoded twv52-a1_track_7.mid
# Encoded duetto09_track_1.mid
# Encoded lupot-fantasia5-a4_track_1.mid
# Encoded mancini-sonata10_track_2.mid
# Encoded hingestonj-fantasia6-a4_track_2.mid
# Encoded 08_the_marie-golde_track_5.mid
# Encoded 04_lullabie_track_4.mid
# Encoded coprarioj-fantasia22-a5_track_4.mid
# Encoded brewert-24-ayre_track_4.mid
# Encoded micor-fantasia19-a4_track_2.mid
# Encoded hingestonj-fantazia7-a3_track_3.mid
# Encoded ferraboscoa-fantasia01-a6_track_1.mid
# Encoded jenkinsj-fantasia08-a3_track_1.mid
# Encoded 08_semper_dowland_track_5.mid
# Encoded hwv362_track_2.mid
# Encoded 11-laorganistabella_track_3.mid
# Encoded canzon199_track_4.mid
# Encoded hingestonj-fantasia5-a4_track_1.mid
# Encoded jenkinsj-fantasia02-a6_track_1.mid
# Encoded 39_pavan_track_2.mid
# Encoded jenkinsj-fantasia14-a3_track_2.mid
# Encoded wardj-fantasia11-a5_track_2.mid
# Encoded byrdw-fantasia1-a4_track_2.mid
# Encoded hingestonj-suite2-a6_track_5.mid
# Encoded micor-pavan1-a4_track_2.mid
# Encoded 12-euterpe_track_1.mid
# Encoded brandenburg4-allegro_track_2.mid
# Encoded 47_pavan_track_5.mid
# Encoded 23_spero_track_4.mid
# Encoded lockem-suite3_track_2.mid
# Encoded twv40-118_track_2.mid
# Encoded gibbonso-fantasia1-a3_track_1.mid
# Encoded jenkinsj-fantasia09-a3_track_1.mid
# Encoded jenkinsj-fantasia4-a4_track_2.mid
# Encoded coprarioj-fantasia36-a5_track_4.mid
# Encoded colemanc-fantasia3-a6_track_6.mid
# Encoded 06-and_i_as_well_as_thou_track_2.mid
# Encoded 35_decrevi_track_2.mid
# Encoded micor-fantasia3-a3_track_1.mid
# Encoded wardj-fantasia6-a5_track_5.mid
# Encoded micor-fantasia5-a3_track_1.mid
# Encoded coprarioj-fantasia02-a5_track_4.mid
# Encoded lupot-fantasia9-a4_track_3.mid
# Encoded coleman-vdgs258-almaine_track_1.mid
# Encoded twv40-103_track_2.mid
# Encoded lawesw-set10-cminor_track_1.mid
# Encoded twv41-f2_track_4.mid
# Encoded 19-my_time_is_spent_track_1.mid
# Encoded 62_the_widowes_myte_track_5.mid
# Encoded byrdw-fantasia1-a6_track_1.mid
# Encoded lawesw-set6-gminor_track_4.mid
# Encoded loeilletjb-sonata-opus24_track_1.mid
# Encoded larolanda_track_3.mid
# Encoded 10-lafeliciana_track_1.mid
# Encoded 13_pavan_track_4.mid
# Encoded peersonm-fantasia6_track_1.mid
# Encoded ferraboscoa-fantasia02-a4_track_2.mid
# Encoded barsantif-sonata4-op1_track_4.mid
# Encoded jenkinsj-fantasia12-a6_track_3.mid
# Encoded twv42-a9_track_1.mid
# Encoded wardj-fantasia6a4_track_4.mid
# Encoded chfetwooder-fantasia1-a3_track_2.mid
# Encoded canzon196_track_3.mid
# Encoded micor-fantasia2-a4_track_4.mid
# Encoded hingestonj-suite4-a5_track_4.mid
# Encoded coprarioj-fantasia04-a3_track_2.mid
# Encoded 17-la_robbata_track_2.mid
# Encoded 50_sic_semper_soleo_track_2.mid
# Encoded lupot-fantasia2-a4_track_2.mid
# Encoded ferraboscoa-fantasia15-a4_track_3.mid
# Encoded coprarioj-fantasia42-a5_track_4.mid
# Encoded ferraboscoa-fantasia03-a6_track_2.mid
# Encoded miltonj-fantasia1_track_1.mid
# Encoded jeffreysg-fantasia5-a3_track_3.mid
# Encoded wardj-fantasia9-a5_track_1.mid
# Encoded hingestonj-suite3-a5_track_4.mid
# Encoded 20_nichols_almand_track_4.mid
# Encoded 08_semper_dowland_track_2.mid
# Encoded twv42f9_track_2.mid
# Encoded twv54-b2_1_track_9.mid
# Encoded coprarioj-fantasia01-a3_track_1.mid
# Encoded hingestonj-suite3-a6_track_4.mid
# Encoded 10-no_hast_but_good_track_1.mid
# Encoded micor-pavan1-a4_track_4.mid
# Encoded wardj-fantasia6a4_track_3.mid
# Encoded wardj-fantasia5-a5_track_1.mid
# Encoded 8-amavi_track_1.mid
# Encoded colemanc-fantasia-a5_track_2.mid
# Encoded 39_pavan_track_3.mid
# Encoded brewert-fantasia1-a4_track_4.mid
# Encoded 37_pavan_track_1.mid
# Encoded lawesw-111-cmajor-fantasia_track_4.mid
# Encoded coprarioj-fantasia3-a6_track_5.mid
# Encoded bassanoj-fantasia4-a5_track_1.mid
# Encoded bassanog-fantasia20-a3_track_3.mid
# Encoded mancini-sonata5_track_2.mid
# Encoded coprarioj-fantasia6-a4_track_3.mid
# Encoded 02-la_canobbia_track_4.mid
# Encoded 02_lachrimae_antiquae_novae_track_1.mid
# Encoded 36_my_selfe_track_1.mid
# Encoded 09-cleio_track_1.mid
# Encoded brandenburg4-presto_track_2.mid
# Encoded weelkest-pavan3_track_5.mid
# Encoded hwv360_track_1.mid
# Encoded 17_paradizo_track_5.mid
# Encoded hingestonj-suite1-a6_track_2.mid
# Encoded lupot-fantasia03-a6_track_3.mid
# Encoded micor-fantasia8-a4_track_2.mid
# Encoded ferraboscoa-fantasia08-a6_track_4.mid
# Encoded jeffreysg-fantasia4-a3_track_3.mid
# Encoded 02_the_teares_of_the_track_4.mid
# Encoded 19_buctons_galiard_track_1.mid
# Encoded 20_nichols_almand_track_1.mid
# Encoded jenkinsj-fantasia15-a4_track_1.mid
# Encoded jenkinsj-fantasia05-a3_track_2.mid
# Encoded jenkinsj-fantasia12-a6_track_6.mid
# Encoded chfetwooder-fantasia3-a3_track_3.mid
# Encoded 14-la_solda_track_3.mid
# Encoded 11_pavan_track_3.mid
# Encoded twv42_d4_track_1.mid
# Encoded 10-lafeliciana_track_2.mid
# Encoded twv40-145_4_track_2.mid
# Encoded flatconsort-vdgs6_track_3.mid
# Encoded 18_digorie_piper_his_galiard_track_4.mid
# Encoded matthesonj-sonata9-a3_track_1.mid
# Encoded lafontana_track_4.mid
# Encoded coprarioj-fantasia02-a3_track_3.mid
# Encoded jenkinsj-fantasia06-a6_track_2.mid
# Encoded mozart-the-magic-flute-papagenos-aria_track_1.mid
# Encoded coleman-vdgs217-almaine_track_1.mid
# Encoded byrdw-fantasia2-a6_track_1.mid
# Encoded brewert-17-ayre_track_4.mid
# Encoded deeringr-fantasia8-a5_track_4.mid
# Encoded 11-white_as_lillies_track_2.mid
# Encoded mancini-sonata4_track_2.mid
# Encoded lupot-fantasia04-a6_track_4.mid
# Encoded peersonm-almaine7_track_1.mid
# Encoded 26_hermoza_track_4.mid
# Encoded twv40-123_track_1.mid
# Encoded 01-la_bevilacqua_track_2.mid
# Encoded coprarioj-fantasia22-a5_track_5.mid
# Encoded 41_pavan_track_5.mid
# Encoded tomkinst-fantasia12-a3_track_3.mid
# Encoded 18-canzon_la_bevilacq_track_4.mid
# Encoded 03_pavan_track_3.mid
# Encoded deeringr-fantasia2-a5_track_1.mid
# Encoded okeoverj-fantasia6-a3_track_3.mid
# Encoded lawesw-set9-bbmajor_track_3.mid
# Encoded cranfordw-fantasia2-a4_track_1.mid
# Encoded hingestonj-fantasia2-a4_track_1.mid
# Encoded loeillet_duette4_track_1.mid
# Encoded jenkinsj-fantasia16-a3_track_3.mid
# Encoded 64_as_it_fell_track_3.mid
# Encoded brewert-21-corant_track_1.mid
# Encoded coprarioj-fantasia07-a3_track_2.mid
# Encoded carwardenj-suite5-31-a_daunce_track_2.mid
# Encoded canzon199_track_2.mid
# Encoded hingestonj-almande1-a4_track_2.mid
# Encoded 05_lachrimae_coactae_track_2.mid
# Encoded 12-la_durante_track_2.mid
# Encoded brewert-01-pavin_track_4.mid
# Encoded wardj-fantasia9-a5_track_3.mid
# Encoded canzona8_track_3.mid
# Encoded canzon187_track_3.mid
# Encoded canzon201_track_3.mid
# Encoded coleman-vdgs314-almaine_track_1.mid
# Encoded micor-pavan3-a5_track_5.mid
# Encoded coprarioj-fantasia13-a5_track_5.mid
# Encoded 10_galliard_track_2.mid
# Encoded bassanog-fantasia20-a3_track_1.mid
# Encoded carwardenj-suite3-19-saraband_track_3.mid
# Encoded 56_almayne_track_1.mid
# Encoded canzonnona_track_1.mid
# Encoded colemanc-fantasia2-a6_track_1.mid
# Encoded cranfordw-fantasia2-a5_track_2.mid
# Encoded fantaziaz740_1_track_3.mid
# Encoded canzon198_track_6.mid
# Encoded ferraboscoa-fantasia14-a4_track_2.mid
# Encoded fantaziaz740_1_track_1.mid
# Encoded weelkest-pavan5_track_1.mid
# Encoded coprarioj-fantasia05-a5_track_3.mid
# Encoded twv40-104_track_2.mid
# Encoded 06_lachrimae_amantis_track_4.mid
# Encoded coprarioj-fantasia05-a3_track_3.mid
# Encoded canzon197_track_6.mid
# Encoded hingestonj-suite2-a5_track_3.mid
# Encoded jenkinsj-fantasia18-a3_track_1.mid
# Encoded jenkinsj-fantasia2-a5_track_2.mid
# Encoded jenkinsj-fantasia13-a4_track_3.mid
# Encoded bassanog-fantasia15-a3_track_3.mid
# Encoded croft-op3-no4_track_2.mid
# Encoded fantazia6_1_track_2.mid
# Encoded 44_nec_invideo_track_2.mid
# Encoded miltonj-fantasia3_track_3.mid
# Encoded whitew-fantasisa4-a6_track_1.mid
# Encoded wardj-fantasia4a4_track_4.mid
# Encoded hingestonj-fantazia8-a3_track_3.mid
# Encoded jenkinsj-fantasia1-a5_track_1.mid
# Encoded matthesonj-sonata10-a3_track_1.mid
# Encoded brewert-14-corant_track_2.mid
# Encoded coleman-vdgs218-saraband_track_2.mid
# Encoded 33_heres_paternus_track_1.mid
# Encoded peersonm-almaine1_track_5.mid
# Encoded triosonataop1no1_track_3.mid
# Encoded twv40-119_track_1.mid
# Encoded 34_muy_linda_track_1.mid
# Encoded eastm-fancy08_track_3.mid
# Encoded whitew-fantasisa2-a6_track_5.mid
# Encoded brewert-fantasia3-a4_track_3.mid
# Encoded 19-my_time_is_spent_track_3.mid
# Encoded 08-sweetlady_track_2.mid
# Encoded 4-hold_right_track_1.mid
# Encoded jenkinsj-fantasia12-a5_track_2.mid
# Encoded matthesonj-sonata3-a3_track_3.mid
# Encoded 32_galliard_track_2.mid
# Encoded jenkinsj-fantasia12-a5_track_5.mid
# Encoded 19_sedet_sola_track_2.mid
# Encoded 14-stay_yet_a_while_track_3.mid
# Encoded peersonm-fantasia4_track_2.mid
# Encoded deeringr-fantasia2-a5_track_4.mid
# Encoded carwardenj-suite4-23-saraband_track_3.mid
# Encoded micor-pavan3-a5_track_2.mid
# Encoded purcellh-fantasia1-a3_track_3.mid
# Encoded hingestonj-suite4-a5_track_5.mid
# Encoded coleman-vdgs010-corant_1_track_2.mid
# Encoded jenkinsj-pavan2-a5_track_1.mid
# Encoded coprarioj-fantasia6-a6_track_3.mid
# Encoded jenkinsj-fantasia03-a6_track_2.mid
# Encoded lupot-fantasia12-a6_track_2.mid
# Encoded 04_lullabie_track_2.mid
# Encoded canzon200_track_1.mid
# Encoded canzon201_track_2.mid
# Encoded 21_george_whitehead_his_almand_track_3.mid
# Encoded micor-pavan3-a4_track_1.mid
# Encoded duetto12_track_2.mid
# Encoded jenkinsj-fantasia17-a4_track_4.mid
# Encoded morley_la_sirena_track_1.mid
# Encoded triosonataop2nr6_1_track_3.mid
# Encoded 09-cleio_track_3.mid
# Encoded 09_pavan_track_1.mid
# Encoded 14-erato_track_2.mid
# Encoded coleman-vdgs258-almaine_track_2.mid
# Encoded qv3.21_track_1.mid
# Encoded matthesonj-sonata8-a3_track_2.mid
# Encoded brewert-04-almaine_track_1.mid
# Encoded ferraboscoa-fantasia03-a4_track_1.mid
# Encoded wardj-fantasia13-a5_track_1.mid
# Encoded twv41f1_track_2.mid
# Encoded hingestonj-almande1-a4_track_1.mid
# Encoded coprarioj-fantasia40-a5_track_2.mid
# Encoded coleman-vdgs115-ecchocorant_track_3.mid
# Encoded coprarioj-fantasia07-a5_track_5.mid
# Encoded byrdw-fantasia2-a6_track_3.mid
# Encoded jenkinsj-fantasia12-a6_track_1.mid
# Encoded jenkinsj-fantasia12-a3_track_2.mid
# Encoded canzondecimasettima_track_2.mid
# Encoded 03-lagallupparevista_track_2.mid
# Encoded carwardenj-suite4-21-aire_track_2.mid
# Encoded jenkinsj-fantasia5-a4_track_3.mid
# Encoded jenkinsj-fantasia3-a4_track_4.mid
# Encoded brewert-23-almaine_track_3.mid
# Encoded jenkinsj-fantasia12-a6_track_5.mid
# Encoded twv40-141_4_track_1.mid
# Encoded coprarioj-fantasia4-a6_track_4.mid
# Encoded barsantif-sonata1-op1_track_2.mid
# Encoded ferraboscoa-fantasia18-a4_track_3.mid
# Encoded coprarioj-fantasia09-a3_track_2.mid
# Encoded canzonsettima_track_1.mid
# Encoded coprarioj-fantasia05-a5_track_1.mid
# Encoded 05-lapomponazza_track_2.mid
# Encoded hingestonj-fantazia3-a3_track_2.mid
# Encoded ravenscroftt-fantasia4-a5_track_1.mid
# Encoded littleconsort-suite7_track_1.mid
# Encoded lawesw-set6-gminor_track_3.mid
# Encoded 30_galliard_track_5.mid
# Encoded tomkinst-fantasia1-a6_track_6.mid
# Encoded hingestonj-almande2-a4_track_3.mid
# Encoded weelkest-pavan3_track_4.mid
# Encoded lawesw-set1-gminor_1_track_3.mid
# Encoded byrdw-fantasia1-a6_track_6.mid
# Encoded 31_the_funerals_track_2.mid
# Encoded coprarioj-fantasia6-a6_track_6.mid
# Encoded micor-fantasia2-a5_track_1.mid
# Encoded jenkinsj-fantasia10-a5_track_3.mid
# Encoded coleman-vdgs202-corant_track_2.mid
# Encoded peersonm-almaine3_track_4.mid
# Encoded coprarioj-fantasia41-a5_track_3.mid
# Encoded coprarioj-fantasia1-a4_track_1.mid
# Encoded coprarioj-fantasia04-a5_track_4.mid
# Encoded 09_henry_umptons_funerall_track_5.mid
# Encoded coprarioj-fantasia08-a3_track_2.mid
# Encoded 28_ecce_quam_bonum_track_4.mid
# Encoded 46_galliard_track_5.mid
# Encoded jenkinsj-fantasia08-a3_track_3.mid
# Encoded jenkinsj-fantasia6-a4_track_4.mid
# Encoded canzon189_track_3.mid
# Encoded ferraboscoa-fantasia16-a4_track_1.mid
# Encoded twv40-102_track_2.mid
# Encoded coprarioj-fantasia06-a3_track_3.mid
# Encoded canzona14_track_4.mid
# Encoded ferraboscoa-fantasia09-a4_track_3.mid
# Encoded 52_galliard_track_5.mid
# Encoded lawesw-set3-cminor_1_track_4.mid
# Encoded tomkinst-fantasia15-a3_track_2.mid
# Encoded ravenscroftt-fantasia2-a5_track_3.mid
# Encoded brewert-07-almaine_track_2.mid
# Encoded 16-la_stella_track_4.mid
# Encoded 7-triumphavi_track_1.mid
# Encoded barsantif-sonata2-op1_track_4.mid
# Encoded 6-vixi_track_5.mid
# Encoded coprarioj-fantasia01-a5_track_2.mid
# Encoded lupot-fantasia3-a4_track_3.mid
# Encoded canzonseconda_track_4.mid
# Encoded 07-laguamina_track_1.mid
# Encoded brewert-21-corant_track_2.mid
# Encoded gibbonso-fantasia1-a3_track_3.mid
# Encoded coprarioj-fantasia07-a3_track_3.mid
# Encoded barsantif-sonata1-op1_track_4.mid
# Encoded 15-come_lets_be_gone_track_3.mid
# Encoded eastm-fancy09_track_2.mid
# Encoded coprarioj-fantasia32-a5_track_5.mid
# Encoded coprarioj-fantasia26-a5_track_3.mid
# Encoded loeillet_duette2_track_1.mid
# Encoded 39_pavan_track_5.mid
# Encoded 58_the_fruit_of_love_track_2.mid
# Encoded coprarioj-fantasia34-a5_track_1.mid
# Encoded gibbonso-fantasia2-a6_track_4.mid
# Encoded coprarioj-fantasia2-a6_track_5.mid
# Encoded 7-triumphavi_track_5.mid
# Encoded jenkinsj-pavin1-bell-a6_track_4.mid
# Encoded deeringr-fantasia3-a5_track_2.mid
# Encoded hingestonj-almande7-a4_track_4.mid
# Encoded jenkinsj-pavan1-a5_track_3.mid
# Encoded tomkinst-pavan2-a5_track_4.mid
# Encoded brewert-fantasia6-a4_track_3.mid
# Encoded jenkinsj-fantasia9-a4_track_1.mid
# Encoded lupot-fantasia13-a4_track_2.mid
# Encoded micor-fantasia5-a3_track_2.mid
# Encoded jenkinsj-fantasia17-a3_track_3.mid
# Encoded duetto16_track_1.mid
# Encoded 11-white_as_lillies_track_3.mid
# Encoded peersonm-fantasia5_track_2.mid
# Encoded twv41-d4_track_2.mid
# Encoded coprarioj-fantasia03-a5_track_5.mid
# Encoded deeringr-fantasia8-a5_track_2.mid
# Encoded duetto06_track_2.mid
# Encoded loeilletjb-sonata-opus26_track_3.mid
# Encoded canzon199_track_5.mid
# Encoded tomkinst-pavan8-a5_track_4.mid
# Encoded coprarioj-fantasia35-a5_track_4.mid
# Encoded jenkinsj-fantasia08-a6_track_3.mid
# Encoded colemanc-fantasia-a5_track_1.mid
# Encoded eastm-fancy12_track_4.mid
# Encoded lupot-fantasia05-a6_track_3.mid
# Encoded twv42f14_track_4.mid
# Encoded 14_henry_noel_his_galiard_track_1.mid
# Encoded 06-la_gambara_track_2.mid
# Encoded weelkest-pavan2_track_5.mid
# Encoded 10-lafeliciana_track_4.mid
# Encoded 54_galliard_track_1.mid
# Encoded canzonprima_track_4.mid
# Encoded mancini-sonata11_track_2.mid
# Encoded lupot-fantasia6-a4_track_3.mid
# Encoded 17_thomas_collier_his_galiard_track_4.mid
# Encoded hiltonj-fantasia1-a3_track_2.mid
# Encoded 04_lullabie_track_3.mid
# Encoded ferraboscoa-fantasia06-a6_track_3.mid
# Encoded 23_spero_track_2.mid
# Encoded 58_the_fruit_of_love_track_4.mid
# Encoded 14_galliard_track_2.mid
# Encoded 06_lachrimae_amantis_track_2.mid
# Encoded whitew-fantasisa1-a5_track_3.mid
# Encoded wardj-fantasia7-a6_track_1.mid
# Encoded twv42-d9_track_1.mid
# Encoded coprarioj-fantasia05-a5_track_5.mid
# Encoded fantaziaz737_1_track_1.mid
# Encoded fantaziaz741_1_track_2.mid
# Encoded 25_patiencia_track_1.mid
# Encoded brewert-11-almaine_track_1.mid
# Encoded lupot-fantasia04-a6_track_3.mid
# Encoded twv41c2_track_4.mid
# Encoded naudot-suite3_track_1.mid
# Encoded jenkinsj-fantasia01-a3_track_2.mid
# Encoded brewert-04-almaine_track_2.mid
# Encoded peersonm-almaine5_track_6.mid
# Encoded jenkinsj-fantasia11-a5_track_3.mid
# Encoded canzondecima_track_4.mid
# Encoded wardj-fantasia2-a6_track_1.mid
# Encoded lockem-suite1_track_4.mid
# Encoded micor-fantasia6-a4_track_2.mid
# Encoded jenkinsj-fantasia02-a3_track_1.mid
# Encoded wardj-fantasia6-a5_track_2.mid
# Encoded blavetm-sonate_4_bbmaj_track_1.mid
# Encoded flatconsort-vdgs10_track_2.mid
# Encoded brewert-22-pavin_track_1.mid
# Encoded twv54-b2_1_track_8.mid
# Encoded canzon198_track_5.mid
# Encoded laleonora_track_3.mid
# Encoded 13-mourning_i_die_track_2.mid
# Encoded micor-fantasia5-a4_track_3.mid
# Encoded ferraboscoa-fantasia23-a4_track_2.mid
# Encoded canzondecimaquinta_track_4.mid
# Encoded micor-fantasia2-a4_track_1.mid
# Encoded peersonm-almaine4_track_2.mid
# Encoded coleman-vdgs195-aire_track_3.mid
# Encoded matthesonj-sonata7-a3_track_2.mid
# Encoded coprarioj-fantasia10-a3_track_3.mid
# Encoded carwardenj-suite5-26-saraband_track_1.mid
# Encoded ferraboscoa-fantasia13-a4_track_4.mid
# Encoded 37_pavan_track_4.mid
# Encoded 51_posthuma_track_1.mid
# Encoded whitew-fantasisa4-a6_track_4.mid
# Encoded fantaziaz742_1_track_2.mid
# Encoded carwardenj-suite5-27-aire_track_1.mid
# Encoded 08-la_furta_track_2.mid
# Encoded carwardenj-suite5-28-corant_track_2.mid
# Encoded tomkinst-pavan5-a5_track_5.mid
# Encoded canzonquinta_track_3.mid
# Encoded lupot-fantasia12-a6_track_1.mid
# Encoded eastm-fancy04_track_4.mid
# Encoded qv3.21_track_2.mid
# Encoded coprarioj-fantasia06-a5_track_2.mid
# Encoded coleman-vdgs117-aire_track_1.mid
# Encoded 13-terpsicore_track_1.mid
# Encoded hingestonj-almande2-a3_track_3.mid
# Encoded loeillet_duette4_track_2.mid
# Encoded twv52-b1_track_1.mid
# Encoded littleconsort-suite10_track_3.mid
# Encoded coprarioj-fantasia19-a5_track_1.mid
# Encoded bassanoj-fantasia1-a5_track_2.mid
# Encoded larizza_track_2.mid
# Encoded coleman-vdgs206-saraband_track_1.mid
# Encoded jenkinsj-fantasia10-a4_track_4.mid
# Encoded whitew-fantasisa3-a6_track_4.mid
# Encoded tallis-third-mode-melody_track_2.mid
# Encoded micor-fantasia4-a5_track_4.mid
# Encoded coprarioj-fantasia22-a5_track_3.mid
# Encoded byrdw-fantasia2-a6_track_6.mid
# Encoded wardj-fantasia2-a6_track_6.mid
# Encoded twv-40-128_3_track_2.mid
# Encoded 07-laguamina_track_2.mid
# Encoded gibbonso-fantasia5-a6_track_4.mid
# Encoded ferraboscoa-fantasia09-a6_track_1.mid
# Encoded 38_galliard_track_2.mid
# Encoded coprarioj-fantasia24-a5_track_4.mid
# Encoded coprarioj-fantasia06-a5_track_3.mid
# Encoded coprarioj-fantasia35-a5_track_5.mid
# Encoded 05_lachrimae_coactae_track_4.mid
# Encoded barsantif-sonata5-op1_track_1.mid
# Encoded carwardenj-suite5-27-aire_track_2.mid
# Encoded wardj-fantasia5-a6_track_5.mid
# Encoded jenkinsj-fantasia09-a6_track_4.mid
# Encoded ferraboscoa-fantasia07-a6_track_6.mid
# Encoded tomkinst-fantasia15-a3_track_1.mid
# Encoded ferraboscoa-fantasia09-a4_track_2.mid
# Encoded 43_amoretta_track_2.mid
# Encoded ferraboscoa-fantasia06-a4_track_1.mid
# Encoded jenkinsj-fantasia17-a5_track_1.mid
# Encoded 01-la_rovattina_track_1.mid
# Encoded jenkinsj-fantasia05-a6_track_4.mid
# Encoded hingestonj-almande1-a3_track_3.mid
# Encoded hingestonj-suite2-a6_track_4.mid
# Encoded 12-la_durante_track_3.mid
# Encoded hingestonj-fantazia7-a3_track_1.mid
# Encoded 28_ecce_quam_bonum_track_5.mid
# Encoded 41_pavan_track_3.mid
# Encoded blankse-fantasia1_track_3.mid
# Encoded brewert-22-pavin_track_4.mid
# Encoded okeoverj-fantasia8-a3_track_2.mid
# Encoded hingestonj-almande7-a3_track_1.mid
# Encoded blankse-fantasia2_track_3.mid
# Encoded peersonm-fantasia2_track_2.mid
# Encoded 03-lagallupparevista_track_1.mid
# Encoded 02_lachrimae_antiquae_novae_track_4.mid
# Encoded hingestonj-fantasia6-a4_track_1.mid
# Encoded 61_wanton_track_2.mid
# Encoded eastm-fancy10_track_1.mid
# Encoded coprarioj-fantasia29-a5_track_3.mid
# Encoded 09-lacamerina_track_1.mid
# Encoded triosonataop2nr4_1_track_2.mid
# Encoded 03_lachrimae_gementes_track_1.mid
# Encoded okeoverj-fantasia8-a3_track_3.mid
# Encoded wardj-fantasia5a4_track_4.mid
# Encoded coprarioj-fantasia3-a4_track_4.mid
# Encoded twv55-a2_track_3.mid
# Encoded lupot-fantasia09-a6_track_2.mid
# Encoded 43_amoretta_track_5.mid
# Encoded coprarioj-fantasia34-a5_track_4.mid
# Encoded brewert-14-corant_track_3.mid
# Encoded ferraboscoa-fantasia05-a6_track_1.mid
# Encoded micor-fantasia18-a4_track_2.mid
# Encoded duetto13_track_2.mid
# Encoded hingestonj-fantasia1-a4_track_4.mid
# Encoded weelkest-pavan1_track_2.mid
# Encoded tomkinst-pavan6-a5_track_3.mid
# Encoded 49_pavana_ploravit_track_5.mid
# Encoded deeringr-fantasia6-a5_track_4.mid
# Encoded gibbonso-fantasia5-a6_track_6.mid
# Encoded peersonm-fantasia5_track_5.mid
# Encoded coprarioj-fantasia39-a5_track_2.mid
# Encoded flatconsort-vdgs9_track_3.mid
# Encoded 06-la_gambara_track_1.mid
# Encoded fantaziaz737_1_track_4.mid
# Encoded jenkinsj-fantasia11-a3_track_3.mid
# Encoded jeffreysg-fantasia5-a3_track_2.mid
# Encoded twv-40-124_3_track_2.mid
# Encoded matthesonj-sonata12-a2_track_2.mid
# Encoded lacortese_track_1.mid
# Encoded wardj-fantasia3-a6_track_3.mid
# Encoded peersonm-fantasia2_track_1.mid
# Encoded coprarioj-fantasia30-a5_track_4.mid
# Encoded littleconsort-suite9_track_3.mid
# Encoded ferraboscoa-fantasia03-a6_track_3.mid
# Encoded loeilletjb-sonata-opus24_track_3.mid
# Encoded wardj-fantasia7-a5_track_3.mid
# Encoded jeffreysg-fantasia4-a3_track_2.mid
# Encoded byrdw-fantasia3-a6_track_4.mid
# Encoded brewert-24-ayre_track_1.mid
# Encoded 01-trip_it_lightly_track_2.mid
# Encoded brandenburg4-andante_track_3.mid
# Encoded jenkinsj-fantasia3-a4_track_2.mid
# Encoded coprarioj-fantasia4-a4_track_3.mid
# Encoded tomkinst-fantasia2-a6_track_4.mid
# Encoded lawesw-110-cminor-aire_track_1.mid
# Encoded lockem-suite5_track_4.mid
# Encoded coleman-vdgs200-saraband_track_3.mid
# Encoded 19-canzon_la_canobbia_track_2.mid
# Encoded martini-plaisir-damour_track_3.mid
# Encoded wardj-fantasia4-a5_track_4.mid
# Encoded 62_the_widowes_myte_track_4.mid
# Encoded 04-larustica_track_2.mid
# Encoded jenkinsj-fantasia9-a5_track_1.mid
# Encoded larosa_track_1.mid
# Encoded 34_muy_linda_track_2.mid
# Encoded peersonm-fantasia5_track_4.mid
# Encoded wardj-fantasia6-a6_track_3.mid
# Encoded micor-fantasia2-a5_track_3.mid
# Encoded fantaziaz743_1_track_3.mid
# Encoded tomkinst-fantasia07-a3_track_1.mid
# Encoded fantaziaz743_1_track_4.mid
# Encoded morley_la_girandola_track_1.mid
# Encoded chfetwooder-fantasia3-a3_track_1.mid
# Encoded 05_the_cradle_track_1.mid
# Encoded lapazza_track_1.mid
# Encoded jenkinsj-fantasia03-a6_track_1.mid
# Encoded hingestonj-fantazia2-a3_track_1.mid
# Encoded 18-canzon_la_bevilacq_track_8.mid
# Encoded qv3.22_track_2.mid
# Encoded twv42_d4_track_3.mid
# Encoded deeringr-fantasia6-a5_track_1.mid
# Encoded ferraboscoa-fantasia02-a6_track_3.mid
# Encoded 22_galliard_track_1.mid
# Encoded 15_giles_hobies_galiard_track_2.mid
# Encoded canzonprima_track_3.mid
# Encoded canzondecimasesta_track_4.mid
# Encoded tomkinst-pavan9-a5_track_2.mid
# Encoded finger-op2-nr2_track_2.mid
# Encoded twv40-106_track_1.mid
# Encoded mancini-sonata4_track_1.mid
# Encoded lockem-suite3_track_1.mid
# Encoded coprarioj-fantasia06-a5_track_4.mid
# Encoded canzon196_track_2.mid
# Encoded whitew-fantasisa4-a6_track_5.mid
# Encoded canzon195_track_3.mid
# Encoded 01-trip_it_lightly_track_1.mid
# Encoded barsantif-sonata2-op1_track_3.mid
# Encoded hiltonj-fantasia3-a3_track_2.mid
# Encoded byrdw-fantasia2-a4_track_2.mid
# Encoded lupot-fantasia03-a6_track_4.mid
# Encoded coleman-vdgs218-saraband_track_3.mid
# Encoded 01_bona_speranza_track_4.mid
# Encoded micor-fantasia19-a4_track_3.mid
# Encoded 64_as_it_fell_track_4.mid
# Encoded jenkinsj-fantasia12-a4_track_3.mid
# Encoded loeillet_duette5_track_1.mid
# Encoded wardj-fantasia1-a5_track_4.mid
# Encoded jenkinsj-fantasia10-a3_track_2.mid
# Encoded micor-fantasia15-a4_track_2.mid
# Encoded lupot-fantasia07-a6_track_2.mid
# Encoded flatconsort-vdgs4_track_2.mid
# Encoded ferraboscoa-fantasia08-a4_track_4.mid
# Encoded 01_bona_speranza_track_5.mid
# Encoded tomkinst-fantasia04-a3_track_2.mid
# Encoded peersonm-fantasia6_track_2.mid
# Encoded 61_wanton_track_1.mid
# Encoded loeilletjb-sonata-opus22_track_2.mid
# Encoded hingestonj-almande2-a4_track_2.mid
# Encoded jenkinsj-fantasia10-a6_track_5.mid
# Encoded 35_decrevi_track_4.mid
# Encoded 01_lachrimae_antiquae_track_2.mid
# Encoded coleman-vdgs116-ecchosaraband_track_3.mid
# Encoded ravenscroftt-fantasia1-a5_track_4.mid
# Encoded ferraboscoa-fantasia05-a4_track_1.mid
# Encoded brewert-19-corant_track_3.mid
# Encoded jenkinsj-fantasia4-a5_track_1.mid
# Encoded hiltonj-fantasia4-a3_track_2.mid
# Encoded weelkest-pavan1_track_3.mid
# Encoded peersonm-fantasia4_track_1.mid
# Encoded ferraboscoa-fantasia08-a4_track_1.mid
# Encoded tomkinst-fantasia06-a3_track_3.mid
# Encoded 2-peccavi_track_1.mid
# Encoded carwardenj-suite3-15-aire_track_3.mid
# Encoded 60_the_honie_suckle_track_3.mid
# Encoded eastm-fancy10_track_2.mid
# Encoded wardj-fantasia4-a6_track_1.mid
# Encoded gibbonso-fantasia2-a3_track_2.mid
# Encoded brandenburg4-andante_track_4.mid
# Encoded brewert-13-almaine_track_1.mid
# Encoded micor-fantasia15-a4_track_4.mid
# Encoded 37_pavan_track_3.mid
# Encoded 53_last_will_and_test_track_5.mid
# Encoded jenkinsj-pavan1-a5_track_5.mid
# Encoded micor-fantasia10-a4_track_4.mid
# Encoded gibbonso-fantasia5-a6_track_3.mid
# Encoded 02_the_teares_of_the_track_1.mid
# Encoded 8-amavi_track_2.mid
# Encoded wardj-fantasia3a4_track_1.mid
# Encoded tomkinst-fantasia05-a3_track_3.mid
# Encoded ferraboscoa-fantasia03-a6_track_5.mid
# Encoded peersonm-almaine2_track_2.mid
# Encoded coleman-vdgs001-almaine_1_track_3.mid
# Encoded peersonm-fantasia7_track_4.mid
# Encoded ferraboscoa-fantasia09-a4_track_1.mid
# Encoded hingestonj-fantazia3-a3_track_1.mid
# Encoded finger-op2-nr1_track_1.mid
# Encoded lawesw-112-cmajor-aire_track_1.mid
# Encoded jenkinsj-pavan1-a5_track_2.mid
# Encoded lupot-fantasia06-a6_track_3.mid
# Encoded brewert-fantasia2-a4_track_2.mid
# Encoded whitew-fantasisa2-a5_track_2.mid
# Encoded mancini-sonata9_track_1.mid
# Encoded 05-la_avogadra_track_3.mid
# Encoded 47_pavan_track_1.mid
# Encoded ferraboscoa-fantasia15-a4_track_4.mid
# Encoded lockem-suite2_track_3.mid
# Encoded peersonm-fantasia3_track_3.mid
# Encoded matthesonj-sonata2-a2_track_1.mid
# Encoded jenkinsj-pavin1-bell-a6_track_3.mid
# Encoded lupot-fantasia1-a4_track_2.mid
# Encoded brewert-12-almaine_track_4.mid
# Encoded micor-pavan1-a4_track_3.mid
# Encoded twv52-a2_track_1.mid
# Encoded whitew-fantasisa2-a5_track_5.mid
# Encoded lupot-fantasia1-a4_track_4.mid
# Encoded canzonnona_track_4.mid
# Encoded 18_the_sighes_track_3.mid
# Encoded peersonm-almaine3_track_1.mid
# Encoded 18_digorie_piper_his_galiard_track_3.mid
# Encoded coleman-vdgs313-almaine_track_3.mid
# Encoded wardj-fantasia7-a6_track_6.mid
# Encoded micor-pavan3-a5_track_3.mid
# Encoded micor-pavan3-a4_track_4.mid
# Encoded chfetwooder-fantasia4-a3_track_3.mid
# Encoded coprarioj-fantasia27-a5_track_1.mid
# Encoded gibbonso-fantasia1-a6_track_5.mid
# Encoded ravenscroftt-fantasia1-a5_track_3.mid
# Encoded lupot-fantasia12-a6_track_3.mid
# Encoded brewert-03-almaine_track_4.mid
# Encoded 33_heres_paternus_track_2.mid
# Encoded matthesonj-sonata1-a2_track_2.mid
# Encoded brandenburg4-allegro_track_1.mid
# Encoded coprarioj-fantasia19-a5_track_3.mid
# Encoded matthesonj-sonata5-a3_track_3.mid
# Encoded 4-penitet_track_4.mid
# Encoded micor-fantasia9-a4_track_4.mid
# Encoded hingestonj-suite4-a5_track_2.mid
# Encoded coleman-vdgs115-ecchocorant_track_1.mid
# Encoded lawesw-110-cminor-aire_track_2.mid
# Encoded jenkinsj-fantasia5-a4_track_2.mid
# Encoded lockem-suite3_track_4.mid
# Encoded tomkinst-fantasia11-a3_track_1.mid
# Encoded ravenscroftt-fantasia2-a5_track_2.mid
# Encoded hingestonj-fantasia3-a4_track_3.mid
# Encoded ferraboscoa-fantasia19-a4_track_3.mid
# Encoded peersonm-fantasia1_track_2.mid
# Encoded jenkinsj-fantasia7-a4_track_1.mid
# Encoded canzondecimaquinta_track_1.mid
# Encoded bassanog-fantasia17-a3_track_1.mid
# Encoded lamallonia_track_3.mid
# Encoded coleman-vdgs111-aire_track_1.mid
# Encoded 15_pavan_track_2.mid
# Encoded micor-fantasia13-a4_track_2.mid
# Encoded hingestonj-suite3-a6_track_2.mid
# Encoded 20_galliard_track_5.mid
# Encoded coleman-vdgs113-saraband_track_2.mid
# Encoded tomkinst-fantasia08-a3_track_2.mid
# Encoded cranfordw-fantasia2-a4_track_4.mid
# Encoded bassanog-fantasia06-a3_track_2.mid
# Encoded coprarioj-fantasia6-a4_track_1.mid
# Encoded gibbonso-fantasia7-a3_track_2.mid
# Encoded jenkinsj-fantasia08-a6_track_5.mid
# Encoded deeringr-fantasia3-a5_track_5.mid
# Encoded twv40-105_track_2.mid
# Encoded jenkinsj-fantasia04-a6_track_2.mid
# Encoded jenkinsj-fantasia2-a5_track_5.mid
# Encoded 05_the_cradle_track_2.mid
# Encoded croft-op3-no5_track_1.mid
# Encoded jenkinsj-fantasia20-a3_track_2.mid
# Encoded coleman-vdgs260-almaine_track_3.mid
# Encoded coleman-vdgs116-ecchosaraband_track_1.mid
# Encoded 11_pavan_track_2.mid
# Encoded colemanc-fantasia-a5_track_3.mid
# Encoded coprarioj-fantasia02-a3_track_1.mid
# Encoded twv52-e1_track_5.mid
# Encoded 07_lachrimae_verae_track_5.mid
# Encoded loeilletjb-sonata-opus23_track_1.mid
# Encoded peersonm-fantasia1_track_6.mid
# Encoded coleman-vdgs119-saraband_track_2.mid
# Encoded littleconsort-suite7_track_2.mid
# Encoded coprarioj-fantasia21-a5_track_2.mid
# Encoded coleman-vdgs312-almaine_track_2.mid
# Encoded littleconsort-suite9_track_1.mid
# Encoded canzon197_track_2.mid
# Encoded coprarioj-fantasia46-a5_track_5.mid
# Encoded ferraboscoa-fantasia08-a6_track_6.mid
# Encoded lupot-fantasia03-a6_track_5.mid
# Encoded coprarioj-fantasia2-a6_track_2.mid
# Encoded 20_galliard_track_4.mid
# Encoded lupot-fantasia03-a6_track_6.mid
# Encoded 23_spero_track_3.mid
# Encoded fantazia6_1_track_3.mid
# Encoded gibbonso-fantasia3-a3_track_1.mid
# Encoded lupot-fantasia12-a4_track_1.mid
# Encoded coprarioj-fantasia39-a5_track_4.mid
# Encoded weelkest-fantasia-a6_track_2.mid
# Encoded eastm-fancy12_track_3.mid
# Encoded whitew-fantasisa2-a6_track_6.mid
# Encoded canzonsettima_track_2.mid
# Encoded lacortese_track_2.mid
# Encoded 01-la_bevilacqua_track_4.mid
# Encoded hingestonj-fantasia8-a4_track_4.mid
# Encoded jenkinsj-fantasia04-a3_track_3.mid
# Encoded croft-op3-no3_track_1.mid
# Encoded jenkinsj-fantasia4-a5_track_5.mid
# Encoded 55_the_night_watch_track_1.mid
# Encoded bassanoj-fantasia4-a5_track_3.mid
# Encoded bassanog-fantasia19-a3_track_2.mid
# Encoded hingestonj-fantazia5-a3_track_1.mid
# Encoded lacornala_track_4.mid
# Encoded 17-fear_not_the_end_track_2.mid
# Encoded jenkinsj-fantasia04-a3_track_1.mid
# Encoded ferraboscoa-fantasia07-a6_track_1.mid
# Encoded jenkinsj-fantasia06-a3_track_3.mid
# Encoded coprarioj-fantasia03-a3_track_1.mid
# Encoded brewert-13-almaine_track_3.mid
# Encoded coprarioj-fantasia25-a5_track_1.mid
# Encoded 18_the_sighes_track_5.mid
# Encoded lupot-fantasia2-a4_track_3.mid
# Encoded ferraboscoa-fantasia02-a6_track_1.mid
# Encoded micor-fantasia7-a3_track_1.mid
# Encoded matthesonj-sonata6-a3_track_2.mid
# Encoded 46_galliard_track_4.mid
# Encoded coprarioj-fantasia37-a5_track_3.mid
# Encoded blankse-fantasia5_track_1.mid
# Encoded coprarioj-fantasia20-a5_track_2.mid
# Encoded 34_muy_linda_track_4.mid
# Encoded coprarioj-fantasia6-a6_track_2.mid
# Encoded lacortese_track_4.mid
# Encoded flatconsort-vdgs12_track_1.mid
# Encoded eastm-fancy02_track_1.mid
# Encoded mancini-sonata11_track_1.mid
# Encoded twv-40-129_3_track_1.mid
# Encoded cranfordw-fantasia2-a5_track_5.mid
# Encoded jenkinsj-fantasia10-a4_track_2.mid
# Encoded lawesw-set2-aminor_1_track_3.mid
# Encoded coprarioj-fantasia02-a5_track_5.mid
# Encoded lupot-fantasia05-a6_track_1.mid
# Encoded canzona8_track_2.mid
# Encoded bassanog-fantasia05-a3_track_1.mid
# Encoded lagratiosa_track_2.mid
# Encoded 09_henry_umptons_funerall_track_1.mid
# Encoded micor-fantasia1-a5_track_1.mid
# Encoded coleman-vdgs195-aire_track_1.mid
# Encoded bassanog-fantasia17-a3_track_2.mid
# Encoded byrdw-fantasia1-a3_track_1.mid
# Encoded twv42-d9_track_3.mid
# Encoded coleman-vdgs114-ecchoaire_track_1.mid
# Encoded 61_wanton_track_5.mid
# Encoded twv41a4_track_3.mid
# Encoded 4-penitet_track_2.mid
# Encoded coprarioj-fantasia30-a5_track_5.mid
# Encoded coprarioj-fantasia12-a5_track_4.mid
# Encoded bassanog-fantasia04-a3_track_3.mid
# Encoded jenkinsj-fantasia5-a4_track_4.mid
# Encoded hingestonj-almande5-a4_track_2.mid
# Encoded jenkinsj-fantasia11-a5_track_1.mid
# Encoded coleman-vdgs203-saraband_track_2.mid
# Encoded brewert-20-almaine_track_2.mid
# Encoded hwv362_track_4.mid
# Encoded twv41c5_track_1.mid
# Encoded lupot-fantasia10-a6_track_6.mid
# Encoded brewert-fantasia1-a4_track_1.mid
# Encoded 21_infernum_track_4.mid
# Encoded hingestonj-suite1-a5_track_5.mid
# Encoded jenkinsj-pavin1-bell-a6_track_6.mid
# Encoded coleman-vdgs203-saraband_track_3.mid
# Encoded flatconsort-vdgs7_track_3.mid
# Encoded ferraboscoa-fantasia02-a4_track_3.mid
# Encoded canzon201_track_9.mid
# Encoded peersonm-fantasia2_track_5.mid
# Encoded brewert-25-almaine_track_3.mid
# Encoded jenkinsj-fantasia12-a3_track_3.mid
# Encoded jenkinsj-fantasia02-a6_track_5.mid
# Encoded lawesw-set8-fmajor_track_3.mid
# Encoded canzon188_track_4.mid
# Encoded lupot-fantasia07-a6_track_3.mid
# Encoded jenkinsj-fantasia16-a3_track_1.mid
# Encoded tomkinst-pavan9-a5_track_5.mid
# Encoded jenkinsj-pavan3-a5_track_2.mid
# Encoded duetto15_track_2.mid
# Encoded chfetwooder-fantasia4-a3_track_2.mid
# Encoded wardj-fantasia2-a5_track_3.mid
# Encoded 40_galliard_track_2.mid
# Encoded brewert-fantasia2-a4_track_3.mid
# Encoded deeringr-fantasia2-a5_track_5.mid
# Encoded coleman-vdgs315-almaine_track_3.mid
# Encoded coprarioj-fantasia25-a5_track_5.mid
# Encoded 18-canzon_la_bevilacq_track_1.mid
# Encoded ferraboscoa-fantasia11-a4_track_4.mid
# Encoded coprarioj-fantasia23-a5_track_1.mid
# Encoded coprarioj-fantasia07-a3_track_1.mid
# Encoded 09_pavan_track_5.mid
# Encoded lawesw-109-cminor-aire_track_2.mid
# Encoded micor-fantasia12-a4_track_4.mid
# Encoded wardj-fantasia5-a6_track_2.mid
# Encoded mancini-sonata7_track_2.mid
# Encoded jenkinsj-fantasia02-a6_track_2.mid
# Encoded blankse-fantasia4_track_1.mid
# Encoded blavetm-sonate_3_fmaj_track_1.mid
# Encoded 07_pavan_track_1.mid
# Encoded morley_la_caccia_track_1.mid
# Encoded 14_galliard_track_3.mid
# Encoded bassanog-fantasia12-a3_track_1.mid
# Encoded coprarioj-fantasia49-a5_track_5.mid
# Encoded coprarioj-fantasia39-a5_track_1.mid
# Encoded lawesw-set6-gminor_track_2.mid
# Encoded whitew-fantasisa6-a6_track_3.mid
# Encoded coprarioj-fantasia6-a6_track_1.mid
# Encoded okeoverj-fantasia1-a3_track_3.mid
# Encoded ferraboscoa-fantasia18-a4_track_4.mid
# Encoded coleman-vdgs199-corant_track_2.mid
# Encoded 08_semper_dowland_track_4.mid
# Encoded brandenburg4-andante_track_7.mid
# Encoded jenkinsj-fantasia03-a3_track_3.mid
# Encoded micor-pavan3-a5_track_4.mid
# Encoded coleman-vdgs011-corant_1_track_3.mid
# Encoded lupot-fantasia10-a4_track_3.mid
# Encoded fantaziaz735_1_track_4.mid
# Encoded twv42_e4_track_3.mid
# Encoded hingestonj-fantasia1-a4_track_1.mid
# Encoded coprarioj-fantasia27-a5_track_5.mid
# Encoded tomkinst-pavan4-a5_track_4.mid
# Encoded coprarioj-fantasia21-a5_track_3.mid
# Encoded 21_george_whitehead_his_almand_track_2.mid
# Encoded ferraboscoa-fantasia04-a6_track_5.mid
# Encoded canzondecimaterza_track_4.mid
# Encoded lupot-fantasia11-a6_track_5.mid
# Encoded wardj-fantasia4-a6_track_3.mid
# Encoded peersonm-almaine5_track_2.mid
# Encoded colemanc-fantasia1-a6_track_4.mid
# Encoded peersonm-almaine4_track_1.mid
# Encoded fantazia6_1_track_1.mid
# Encoded coprarioj-fantasia42-a5_track_1.mid
# Encoded laradivila_track_1.mid
# Encoded jenkinsj-fantasia07-a3_track_2.mid
# Encoded 05-my_lovely_phillis_track_3.mid
# Encoded 4-penitet_track_3.mid
# Encoded flatconsort-vdgs2_track_3.mid
# Encoded hiltonj-fantasia1-a3_track_3.mid
# Encoded coprarioj-fantasia33-a5_track_5.mid
# Encoded brewert-fantasia6-a4_track_2.mid
# Encoded bassanog-fantasia04-a3_track_2.mid
# Encoded jenkinsj-fantasia1-a4_track_1.mid
# Encoded coprarioj-fantasia22-a5_track_1.mid
# Encoded labovia_track_1.mid
# Encoded ferraboscoa-fantasia16-a4_track_2.mid
# Encoded ferraboscoa-fantasia23-a4_track_1.mid
# Encoded 09-la_ugona_track_2.mid
# Encoded byrdw-fantasia1-a4_track_1.mid
# Encoded coprarioj-fantasia27-a5_track_2.mid
# Encoded jenkinsj-fantasia11-a6_track_2.mid
# Encoded 12_earle_of_essex_galiard_track_3.mid
# Encoded ferraboscoa-fantasia09-a6_track_5.mid
# Encoded coprarioj-fantasia08-a5_track_5.mid
# Encoded jenkinsj-fantasia7-a5_track_2.mid
# Encoded wardj-fantasia6-a5_track_1.mid
# Encoded jenkinsj-fantasia8-a5_track_1.mid
# Encoded duetto20_track_2.mid
# Encoded lawesw-108-cminor-fantasia_track_2.mid
# Encoded tomkinst-pavan2-a5_track_1.mid
# Encoded gibbonso-fantasia5-a3_track_2.mid
# Encoded 19_sedet_sola_track_3.mid
# Encoded carwardenj-suite5-25-corant_track_3.mid
# Encoded hingestonj-fantazia5-a3_track_2.mid
# Encoded jenkinsj-fantasia04-a3_track_2.mid
# Encoded loeilletjb-sonata-opus22_track_3.mid
# Encoded 16-eurania_track_2.mid
# Encoded lawesw-set9-bbmajor_track_1.mid
# Encoded okeoverj-fantasia7-a3_track_3.mid
# Encoded coprarioj-fantasia32-a5_track_2.mid
# Encoded jenkinsj-fantasia03-a6_track_6.mid
# Encoded twv40-148_4_track_1.mid
# Encoded hingestonj-suite1-a5_track_2.mid
# Encoded coprarioj-fantasia45-a5_track_3.mid
# Encoded 14_galliard_track_4.mid
# Encoded coleman-vdgs200-saraband_track_1.mid
# Encoded jenkinsj-fantasia13-a5_track_2.mid
# Encoded 27_the_image_of_melan_track_5.mid
# Encoded whitew-fantasisa5-a6_track_2.mid
# Encoded twv51-c1_track_2.mid
# Encoded wardj-fantasia7-a6_track_2.mid
# Encoded bassanog-fantasia20-a3_track_2.mid
# Encoded brewert-13-almaine_track_4.mid
# Encoded bassanog-fantasia03-a3_track_1.mid
# Encoded brewert-13-almaine_track_2.mid
# Encoded brewert-21-corant_track_3.mid
# Encoded jenkinsj-fantasia7-a5_track_5.mid
# Encoded coleman-vdgs006-almaine_1_track_2.mid
# Encoded twv52-a1_track_2.mid
# Encoded coprarioj-fantasia18-a5_track_4.mid
# Encoded coprarioj-fantasia30-a5_track_3.mid
# Encoded lupot-fantasia11-a4_track_1.mid
# Encoded hingestonj-suite2-a6_track_1.mid
# Encoded triosonataop2nr6_1_track_1.mid
# Encoded wardj-fantasia9-a5_track_5.mid
# Encoded micor-pavan2-a4_track_4.mid
# Encoded mancini-sonata5_track_1.mid
# Encoded coprarioj-fantasia06-a3_track_2.mid
# Encoded duetto05_track_2.mid
# Encoded jenkinsj-fantasia3-a5_track_4.mid
# Encoded hwv362_track_1.mid
# Encoded canzonduodecima_track_1.mid
# Encoded lupot-fantasia08-a6_track_1.mid
# Encoded lawesw-set7-cmajor_track_3.mid
# Encoded brewert-24-ayre_track_3.mid
# Encoded wardj-fantasia1-a6_track_1.mid
# Encoded canzondecima_track_1.mid
# Encoded hingestonj-fantazia1-a3_track_3.mid
# Encoded cranfordw-fantasia1-a5_track_3.mid
# Encoded 16-i_cannot_stay_track_1.mid
# Encoded micor-fantasia2-a5_track_5.mid
# Encoded tomkinst-pavan6-a5_track_1.mid
# Encoded coprarioj-fantasia2-a4_track_4.mid
# Encoded ferraboscoa-fantasia07-a6_track_4.mid
# Encoded lupot-fantasia04-a6_track_2.mid
# Encoded jenkinsj-fantasia9-a5_track_4.mid
# Encoded barsantif-sonata5-op1_track_2.mid
# Encoded coleman-vdgs219-corant_track_3.mid
# Encoded coleman-vdgs112-corant_track_1.mid
# Encoded ferraboscoa-fantasia07-a4_track_2.mid
# Encoded ferraboscoa-fantasia21-a4_track_4.mid
# Encoded peersonm-fantasia1_track_3.mid
# Encoded jenkinsj-fantasia5-a4_track_1.mid
# Encoded canzon197_track_4.mid
# Encoded hingestonj-almande7-a4_track_1.mid
# Encoded hiltonj-fantasia3-a3_track_3.mid
# Encoded canzon186_track_1.mid
# Encoded lawesw-set5-cmajor_1_track_1.mid
# Encoded 59_the_choise_track_1.mid
# Encoded coleman-vdgs001-almaine_1_track_1.mid
# Encoded 40_galliard_track_3.mid
# Encoded twv42f14_track_2.mid
# Encoded 16_galliard_track_3.mid
# Encoded canzon201_track_4.mid
# Encoded carwardenj-suite3-15-aire_track_1.mid
# Encoded colemanc-fantasia4-a6_track_1.mid
# Encoded coprarioj-fantasia27-a5_track_3.mid
# Encoded coprarioj-fantasia46-a5_track_4.mid
# Encoded micor-fantasia6-a4_track_4.mid
# Encoded ferraboscoa-fantasia12-a4_track_2.mid
# Encoded wardj-fantasia3-a6_track_4.mid
# Encoded hingestonj-almande5-a3_track_1.mid
# Encoded bassanoj-fantasia2-a5_track_5.mid
# Encoded canzona13_track_2.mid
# Encoded coprarioj-fantasia24-a5_track_3.mid
# Encoded lupot-fantasia11-a6_track_4.mid
# Encoded lafaustinella_track_2.mid
# Encoded 18_digorie_piper_his_galiard_track_1.mid
# Encoded micor-fantasia10-a4_track_2.mid
# Encoded coprarioj-fantasia28-a5_track_4.mid
# Encoded ferraboscoa-fantasia08-a6_track_3.mid
# Encoded bassanog-fantasia03-a3_track_3.mid
# Encoded canzonottava_track_1.mid
# Encoded coleman-vdgs009-corant_1_track_2.mid
# Encoded lupot-fantasia04-a6_track_1.mid
# Encoded jenkinsj-fantasia7-a4_track_2.mid
# Encoded 40_galliard_track_4.mid
# Encoded 45_pavan_track_3.mid
# Encoded 54_galliard_track_3.mid
# Encoded coleman-vdgs201-aire_track_1.mid
# Encoded bassanog-fantasia17-a3_track_3.mid
# Encoded ferraboscoa-fantasia21-a4_track_1.mid
# Encoded micor-fantasia5-a4_track_1.mid
# Encoded finger-op2-nr3_track_1.mid
# Encoded 15-come_lets_be_gone_track_2.mid
# Encoded gibbonso-fantasia2-a6_track_2.mid
# Encoded ferraboscoa-fantasia03-a6_track_1.mid
# Encoded hingestonj-fantasia4-a4_track_3.mid
# Encoded 04_lachrimae_tristes_track_2.mid
# Encoded jenkinsj-fantasia9-a5_track_3.mid
# Encoded wardj-fantasia3a4_track_3.mid
# Encoded coprarioj-fantasia38-a5_track_1.mid
# Encoded duetto19_track_1.mid
# Encoded okeoverj-fantasia3-a3_track_2.mid
# Encoded wardj-fantasia10-a5_track_3.mid
# Encoded 2-i_as_well_track_1.mid
# Encoded chfetwooder-fantasia4-a3_track_1.mid
# Encoded fantaziaz736_1_track_4.mid
# Encoded ferraboscoa-fantasia10-a4_track_2.mid
# Encoded qv3.25_track_2.mid
# Encoded jenkinsj-fantasia4-a4_track_3.mid
# Encoded bassanoj-fantasia1-a5_track_4.mid
# Encoded fantaziaz743_1_track_1.mid
# Encoded coprarioj-fantasia46-a5_track_2.mid
# Encoded coprarioj-fantasia3-a6_track_6.mid
# Encoded micor-fantasia2-a4_track_2.mid
# Encoded whitew-fantasisa2-a6_track_3.mid
# Encoded hingestonj-suite1-a6_track_4.mid
# Encoded hingestonj-fantasia4-a4_track_2.mid
# Encoded 50_sic_semper_soleo_track_5.mid
# Encoded loeilletjb-sonata-opus21_track_3.mid
# Encoded tomkinst-pavan1-a5_track_2.mid
# Encoded whitew-fantasisa5-a6_track_4.mid
# Encoded twv40-105_track_1.mid
# Encoded jenkinsj-fantasia7-a5_track_4.mid
# Encoded byrdw-fantasia1-a4_track_4.mid
# Encoded 38_galliard_track_4.mid
# Encoded byrdw-fantasia4-a3_track_3.mid
# Encoded brewert-fantasia3-a4_track_2.mid
# Encoded ferraboscoa-fantasia13-a4_track_3.mid
# Encoded twv40-123_track_2.mid
# Encoded 07_pavan_track_4.mid
# Encoded coprarioj-fantasia01-a5_track_4.mid
# Encoded carwardenj-suite3-16-saraband_track_2.mid
# Encoded lupot-fantasia07-a6_track_6.mid
# Encoded 11-laorganistabella_track_2.mid
# Encoded coleman-vdgs388-corant_track_2.mid
# Encoded 07-la_fenarola_track_1.mid
# Encoded 42_galliard_track_1.mid
# Encoded 7-ut_re_me_track_2.mid
# Encoded coprarioj-fantasia40-a5_track_5.mid
# Encoded bassanog-fantasia09-a3_track_2.mid
# Encoded 05_the_cradle_track_4.mid
# Encoded tomkinst-pavan7-a5_track_4.mid
# Encoded jenkinsj-fantasia11-a6_track_3.mid
# Encoded coleman-vdgs219-corant_track_2.mid
# Encoded 57_almaine_track_1.mid
# Encoded 22_galliard_track_2.mid
# Encoded brandenburg4-andante_track_8.mid
# Encoded coprarioj-fantasia26-a5_track_2.mid
# Encoded loeillet_duette3_track_2.mid
# Encoded laradivila_track_2.mid
# Encoded coprarioj-fantasia16-a5_track_5.mid
# Encoded twv42c1_track_2.mid
# Encoded cranfordw-fantasia3-a4_track_3.mid
# Encoded brewert-16-almaine_track_2.mid
# Encoded ravenscroftt-fantasia4-a5_track_4.mid
# Encoded colemanc-fantasia1-a6_track_6.mid
# Encoded tomkinst-pavan1-a5_track_5.mid
# Encoded tomkinst-fantasia14-a3_track_3.mid
# Encoded hingestonj-almande4-a3_track_1.mid
# Encoded matthesonj-sonata4-a3_track_1.mid
# Encoded twv42c1_track_5.mid
# Encoded coleman-vdgs204-aire_track_2.mid
# Encoded 38_galliard_track_1.mid
# Encoded brewert-26-corant_track_4.mid
# Encoded 03-la_maggia_track_1.mid
# Encoded coleman-vdgs217-almaine_track_2.mid
# Encoded hwv365_track_1.mid
# Encoded coleman-vdgs008-almaine_1_track_2.mid
# Encoded hingestonj-almande7-a4_track_3.mid
# Encoded ferraboscoa-fantasia16-a4_track_4.mid
# Encoded micor-fantasia3-a4_track_3.mid
# Encoded micor-fantasia11-a4_track_2.mid
# Encoded blavetm-sonate_1_gmin_track_1.mid
# Encoded canzondecimasesta_track_3.mid
# Encoded 02-turne_round_about_track_2.mid
# Encoded ferraboscoa-fantasia03-a4_track_4.mid
# Encoded 08_semper_dowland_track_3.mid
# Encoded micor-fantasia3-a4_track_2.mid
# Encoded weelkest-pavan2_track_2.mid
# Encoded 1-desperavi_track_3.mid
# Encoded littleconsort-suite9_track_2.mid
# Encoded micor-fantasia9-a4_track_3.mid
# Encoded ravenscroftt-fantasia4-a5_track_3.mid
# Encoded twv42-g9_track_3.mid
# Encoded blavetm-sonate_6_cmaj_track_1.mid
# Encoded lockem-suite6_track_1.mid
# Encoded coprarioj-fantasia08-a3_track_3.mid
# Encoded coprarioj-fantasia14-a5_track_1.mid
# Encoded 17-la_robbata_track_3.mid
# Encoded brandenburg4-andante_track_1.mid
# Encoded twv42c1_track_4.mid
# Encoded mancini-sonata12_track_2.mid
# Encoded wardj-fantasia6a4_track_2.mid
# Encoded coprarioj-fantasia6-a4_track_4.mid
# Encoded hingestonj-fantasia5-a4_track_2.mid
# Encoded mancini-sonata2_track_1.mid
# Encoded micor-fantasia7-a3_track_3.mid
# Encoded micor-fantasia4-a3_track_2.mid
# Encoded cranfordw-fantasia1-a5_track_5.mid
# Encoded cranfordw-fantasia4-a4_track_2.mid
# Encoded 02_lachrimae_antiquae_novae_track_5.mid
# Encoded 19_buctons_galiard_track_2.mid
# ...
# Encoded byrdw-fantasia2-a3_track_2.mid
# Encoded coleman-vdgs003-corant_1_track_2.mid
# Encoded coprarioj-fantasia2-a6_track_3.mid
# Encoded jenkinsj-fantasia5-a5_track_2.mid
# Encoded 11_pavan_track_1.mid
# Encoded canzon189_track_1.mid
# Encoded wardj-fantasia1-a5_track_3.mid
# Encoded 51_posthuma_track_5.mid
# Encoded coprarioj-fantasia34-a5_track_5.mid
# Encoded hingestonj-fantasia2-a4_track_2.mid
# Encoded brewert-fantasia3-a4_track_1.mid
# Encoded 09_pavan_track_4.mid
# Encoded coprarioj-fantasia5-a4_track_2.mid
# Encoded 16-la_stella_track_3.mid
# Encoded micor-fantasia3-a5_track_4.mid
# Encoded 47_pavan_track_4.mid
# Encoded 01_lachrimae_antiquae_track_4.mid
# Encoded hingestonj-almande3-a3_track_1.mid
# Encoded coleman-vdgs314-almaine_track_3.mid
# Encoded 63_the_fairie-round_track_2.mid
# Encoded 06_the_new_yeeres_gif_track_4.mid
# Encoded carwardenj-suite3-17-aire_track_2.mid
# Encoded gibbonso-fantasia3-a6_track_4.mid
# Encoded naudot-suite1_track_1.mid
# Encoded coprarioj-fantasia31-a5_track_4.mid
# Encoded 07_lachrimae_verae_track_4.mid
# Encoded jenkinsj-fantasia10-a3_track_3.mid
# Encoded coprarioj-fantasia33-a5_track_2.mid
# Encoded 10-no_hast_but_good_track_2.mid
# Encoded hingestonj-fantazia9-a3_track_1.mid
# Encoded trioqv2-2_track_2.mid
# Encoded mancini-sonata2_track_2.mid
# Encoded canzonsesta_track_2.mid
# Encoded jenkinsj-fantasia3-a4_track_3.mid
# Encoded coprarioj-fantasia37-a5_track_4.mid
# Encoded weelkest-pavan2_track_1.mid
# Encoded wardj-fantasia5-a6_track_4.mid
# Encoded coleman-vdgs198-aire_track_2.mid
# Encoded coprarioj-fantasia28-a5_track_2.mid
# Encoded twv42-c2_track_3.mid
# Encoded brewert-11-almaine_track_3.mid
# Encoded 10-lafeliciana_track_3.mid
# Encoded mancini-sonata12_track_1.mid
# Encoded jenkinsj-fantasia05-a6_track_3.mid
# Encoded coprarioj-fantasia04-a5_track_1.mid
# Encoded twv40-104_track_1.mid
# Encoded lamallonia_track_1.mid
# Encoded lupot-fantasia3-a4_track_4.mid
# Encoded hingestonj-fantazia5-a3_track_3.mid
# Encoded miltonj-fantasia3_track_2.mid
# Encoded 46_galliard_track_2.mid
# Encoded whitew-fantasisa2-a6_track_1.mid
# Encoded coprarioj-fantasia11-a5_track_1.mid
# Encoded lawesw-set3-cminor_1_track_1.mid
# Encoded peersonm-fantasia3_track_2.mid
# Encoded gibbonso-fantasia2-a3_track_3.mid
# Encoded twv51-c1_track_3.mid
# Encoded fantaziaz741_1_track_3.mid
# Encoded jenkinsj-fantasia21-a3_track_1.mid
# Encoded jenkinsj-fantasia01-a6_track_1.mid
# Encoded jenkinsj-fantasia19-a3_track_1.mid
# Encoded jenkinsj-fantasia10-a6_track_3.mid
# Encoded micor-pavan2-a5_track_1.mid
# Encoded wardj-fantasia1-a5_track_5.mid
# Encoded twv52-a1_track_6.mid
# Encoded jenkinsj-pavan3-a5_track_1.mid
# Encoded jenkinsj-pavan3-a5_track_3.mid
# Encoded coprarioj-fantasia10-a5_track_5.mid
# Encoded tomkinst-fantasia16-a3_track_2.mid
# Encoded lawesw-set9-bbmajor_track_5.mid
# Encoded tomkinst-pavan4-a5_track_2.mid
# Encoded flatconsort-vdgs11_track_2.mid
# Encoded barsantif-sonata5-op1_track_4.mid
# Encoded tomkinst-fantasia09-a3_track_3.mid
# Encoded barsantif-sonata6-op1_track_3.mid
# Encoded canzona14_track_3.mid
# Encoded jenkinsj-fantasia12-a6_track_4.mid
# Encoded deeringr-fantasia4-a5_track_4.mid
# Encoded ferraboscoa-fantasia02-a6_track_6.mid
# Encoded jeffreysg-fantasia1-a3_track_1.mid
# Encoded jenkinsj-fantasia02-a6_track_4.mid
# Encoded barsantif-sonata6-op1_track_2.mid
# Encoded 30_galliard_track_1.mid
# Encoded 3-both_alike_track_2.mid
# Encoded loeillet_duette6_track_1.mid
# Encoded whitew-fantasisa1-a5_track_2.mid
# Encoded lawesw-set10-cminor_track_2.mid
# Encoded ferraboscoa-fantasia22-a4_track_3.mid
# Encoded canzonseconda_track_3.mid
# Encoded finger-op2-nr6_track_2.mid
# Encoded micor-fantasia16-a4_track_1.mid
# Encoded coleman-vdgs204-aire_track_1.mid
# Encoded 22_galliard_track_4.mid
# Encoded 20-smooth_and_soft_track_2.mid
# Encoded hiltonj-fantasia5-a3_track_2.mid
# Encoded tomkinst-pavan9-a5_track_4.mid
# Encoded 44_nec_invideo_track_5.mid
# Encoded coleman-vdgs201-aire_track_3.mid
# Encoded 04-larustica_track_4.mid
# Encoded 01-la_bevilacqua_track_1.mid
# Encoded coprarioj-fantasia25-a5_track_3.mid
# Encoded coprarioj-fantasia43-a5_track_3.mid
# Encoded twv40-143_4_track_1.mid
# Encoded twv54-b2_1_track_2.mid
# Encoded 43_amoretta_track_4.mid
# Encoded coleman-vdgs205-corant_track_2.mid
# Encoded coleman-vdgs202-corant_track_3.mid
# Encoded twv52-b1_track_3.mid
# Encoded lupot-fantasia08-a6_track_2.mid
# Encoded coleman-vdgs007-corant_1_track_3.mid
# Encoded micor-fantasia3-a4_track_1.mid
# Encoded whitew-fantasisa3-a5_track_2.mid
# Encoded 04-la_martinenga_track_2.mid
# Encoded ferraboscoa-fantasia05-a4_track_3.mid
# Encoded canzon201_track_1.mid
# Encoded 11_pavan_track_5.mid
# Encoded duetto10_track_2.mid
# Encoded jenkinsj-fantasia21-a3_track_2.mid
# Encoded 03-la_maggia_track_2.mid
# Encoded wardj-fantasia1-a5_track_1.mid
# Encoded canzonvigesimaprima_track_3.mid
# Encoded flatconsort-vdgs4_track_1.mid
# Encoded twv52-e1_track_2.mid
# Encoded mozart-the-impresario-overture-1_track_1.mid
# Encoded blavetm-sonate_5_fmin_track_1.mid
# Encoded micor-fantasia3-a5_track_1.mid
# Encoded twv52-f1_track_6.mid
# Encoded twv-40-125_3_track_2.mid
# Encoded jenkinsj-fantasia5-a5_track_1.mid
# Encoded canzon197_track_3.mid
# Encoded coprarioj-fantasia37-a5_track_1.mid
# Encoded peersonm-fantasia7_track_2.mid
# Encoded coprarioj-fantasia4-a4_track_1.mid
# Encoded 12-la_durante_track_4.mid
# Encoded micor-fantasia3-a4_track_4.mid
# Encoded 45_pavan_track_4.mid
# Encoded 53_last_will_and_test_track_4.mid
# Encoded 26_hermoza_track_3.mid
# Encoded gibbonso-fantasia4-a6_track_2.mid
# Encoded twv42f9_track_1.mid
# Encoded 65_heigh_ho_holiday_track_4.mid
# Encoded brandenburg4-allegro_track_6.mid
# Encoded coprarioj-fantasia34-a5_track_3.mid
# Encoded matthesonj-sonata5-a3_track_2.mid
# Encoded bassanog-fantasia13-a3_track_1.mid
# Encoded wardj-fantasia4-a5_track_3.mid
# Encoded triosonataop2nr4_1_track_1.mid
# Encoded ferraboscoa-fantasia07-a4_track_1.mid
# Encoded jenkinsj-fantasia08-a6_track_6.mid
# Encoded 16_galliard_track_5.mid
# Encoded 2-peccavi_track_2.mid
# Encoded okeoverj-fantasia5-a3_track_1.mid
# Encoded brewert-07-almaine_track_1.mid
# Encoded twv41a6_track_2.mid
# Encoded twv41a6_track_3.mid
# Encoded 04-la_martinenga_track_3.mid
# Encoded coleman-vdgs196-corant_track_1.mid
# Encoded twv-40-129_3_track_2.mid
# Encoded wardj-fantasia9-a5_track_2.mid
# Encoded coprarioj-fantasia37-a5_track_5.mid
# Encoded carwardenj-suite4-22-corant_track_2.mid
# Encoded 36_my_selfe_track_4.mid
# Encoded twv42c2maj_track_4.mid
# Encoded hingestonj-almande2-a4_track_4.mid
# Encoded 5-credidi_track_4.mid
# Encoded 12_galliard_track_3.mid
# Encoded tomkinst-fantasia09-a3_track_2.mid
# Encoded wardj-fantasia2-a6_track_3.mid
# Encoded ferraboscoa-fantasia07-a6_track_2.mid
# Encoded lawesw-set10-cminor_track_6.mid
# Encoded carwardenj-suite4-21-aire_track_3.mid
# Encoded byrdw-fantasia1-a6_track_4.mid
# Encoded lupot-fantasia06-a6_track_6.mid
# Encoded coprarioj-fantasia2-a6_track_1.mid
# Encoded larolanda_track_4.mid
# Encoded 55_the_night_watch_track_4.mid
# Encoded lupot-fantasia11-a4_track_3.mid
# Encoded 54_galliard_track_2.mid
# Encoded 48_galliard_track_2.mid
# Encoded canzona8_track_1.mid
# Encoded miltonj-fantasia1_track_5.mid
# Encoded coleman-vdgs221-corant_track_2.mid
# Encoded coprarioj-fantasia16-a5_track_1.mid
# Encoded finger-op2-nr5_track_2.mid
# Encoded ferraboscoa-fantasia17-a4_track_3.mid
# Encoded canzon197_track_5.mid
# Encoded coprarioj-fantasia13-a5_track_4.mid
# Encoded okeoverj-fantasia7-a3_track_1.mid
# Encoded peersonm-almaine7_track_5.mid
# Encoded wardj-fantasia4a4_track_2.mid
# Encoded miltonj-fantasia3_track_1.mid
# Encoded hingestonj-almande3-a4_track_1.mid
# Encoded tomkinst-pavan3-a5_track_1.mid
# Encoded 12_earle_of_essex_galiard_track_2.mid
# Encoded 57_almaine_track_4.mid
# Encoded jenkinsj-fantasia7-a5_track_1.mid
# Encoded fantaziaz739_1_track_4.mid
# Encoded eastm-fancy08_track_1.mid
# Encoded 17_thomas_collier_his_galiard_track_5.mid
# Encoded coprarioj-fantasia4-a6_track_3.mid
# Encoded wardj-fantasia1-a6_track_2.mid
# Encoded coprarioj-fantasia03-a3_track_2.mid
# Encoded jenkinsj-fantasia01-a3_track_3.mid
# Encoded cranfordw-fantasia2-a5_track_4.mid
# Encoded cranfordw-fantasia2-a5_track_3.mid
# Encoded whitew-fantasisa6-a6_track_4.mid
# Encoded hingestonj-fantasia3-a4_track_4.mid
# Encoded canzon199_track_1.mid
# Encoded jenkinsj-fantasia13-a3_track_2.mid
# Encoded 5-draw_out_track_1.mid
# Encoded hingestonj-almande3-a4_track_4.mid
# Encoded morley_il_lamento_track_2.mid
# Encoded brewert-01-pavin_track_1.mid
# Encoded hingestonj-almande8-a4_track_2.mid
# Encoded canzondecimaottava_track_4.mid
# Encoded twv40-121_track_1.mid
# Encoded tomkinst-fantasia2-a6_track_3.mid
# Encoded qv3.24_track_1.mid
# Encoded coprarioj-fantasia09-a5_track_3.mid
# Encoded 57_almaine_track_3.mid
# Encoded ferraboscoa-fantasia07-a6_track_5.mid
# Encoded canzona9_track_4.mid
# Encoded laradivila_track_4.mid
# Encoded brewert-02-pavin_track_4.mid
# Encoded byrdw-fantasia1-a6_track_5.mid
# Encoded twv42_h4_track_2.mid
# Encoded jenkinsj-fantasia4-a5_track_3.mid
# Encoded carwardenj-suite4-20-pavan_track_3.mid
# Encoded finger-op2-nr4_track_2.mid
# Encoded canzona13_track_1.mid
# Encoded peersonm-almaine1_track_1.mid
# Encoded jenkinsj-fantasia16-a5_track_3.mid
# Encoded ravenscroftt-fantasia3-a5_track_4.mid
# Encoded whitew-fantasisa5-a6_track_6.mid
# Encoded twv42-a4_track_4.mid
# Encoded ferraboscoa-fantasia23-a4_track_4.mid
# Encoded byrdw-fantasia4-a3_track_1.mid
# Encoded ferraboscoa-fantasia19-a4_track_4.mid
# Encoded 10_galliard_track_1.mid
# Encoded jeffreysg-fantasia6-a3_track_2.mid
# Encoded 18-canzon_la_bevilacq_track_3.mid
# Encoded 33_heres_paternus_track_4.mid
# Encoded 17_paradizo_track_4.mid
# Encoded brewert-09-ayre_track_3.mid
# Encoded wardj-fantasia3-a6_track_6.mid
# Encoded 13_john_souch_his_galiard_track_2.mid
# Encoded 8-amavi_track_4.mid
# Encoded lupot-fantasia13-a4_track_4.mid
# Encoded 05_the_cradle_track_3.mid
# Encoded 04-softly_for_falling_track_3.mid
# Encoded gibbonso-fantasia5-a6_track_5.mid
# Encoded wallop-the-spot_track_1.mid
# Encoded carwardenj-suite3-18-corant_track_3.mid
# Encoded 16-i_cannot_stay_track_2.mid
# Encoded brewert-23-almaine_track_2.mid
# Encoded lupot-fantasia12-a4_track_2.mid
# Encoded coprarioj-fantasia6-a4_track_2.mid
# Encoded coprarioj-fantasia38-a5_track_3.mid
# Encoded 17_paradizo_track_2.mid
# Encoded duetto19_track_2.mid
# Encoded 16_nicholas_gryffith_his_galiard_track_4.mid
# Encoded tomkinst-pavan1-a5_track_4.mid
# Encoded lupot-fantasia10-a4_track_2.mid
# Encoded morley_il_grillo_track_2.mid
# Encoded coprarioj-fantasia19-a5_track_4.mid
# Encoded canzonvigesima_track_1.mid
# Encoded twv42_h4_track_3.mid
# Encoded lapazza_track_4.mid
# Encoded martini-plaisir-damour_track_1.mid
# Encoded 11_king_of_denmarks_galiard_track_4.mid
# Encoded purcellh-fantasia1-a3_track_1.mid
# Encoded hwv369_track_4.mid
# Encoded flatconsort-vdgs6_track_1.mid
# Encoded lupot-fantasia5-a4_track_3.mid
# Encoded wardj-fantasia5-a6_track_6.mid
# Encoded 8-dally_not_track_1.mid
# Encoded ferraboscoa-fantasia01-a4_track_1.mid
# Encoded byrdw-fantasia3-a3_track_3.mid
# Encoded coprarioj-fantasia49-a5_track_2.mid
# Encoded gibbonso-fantasia9-a3_track_3.mid
# Encoded matthesonj-sonata4-a3_track_2.mid
# Encoded hingestonj-almande6-a3_track_1.mid
# Encoded coprarioj-fantasia43-a5_track_2.mid
# Encoded micor-fantasia1-a3_track_3.mid
# Encoded 07-love_is_a_toye_track_2.mid
# Encoded micor-pavan3-a4_track_2.mid
# Encoded byrdw-fantasia2-a6_track_2.mid
# Encoded coprarioj-fantasia5-a4_track_1.mid
# Encoded coleman-vdgs011-corant_1_track_2.mid
# Encoded 19_sedet_sola_track_5.mid
# Encoded weelkest-pavan6_track_5.mid
# Encoded 19-canzon_la_canobbia_track_7.mid
# Encoded jenkinsj-fantasia09-a6_track_6.mid
# Encoded cranfordw-fantasia1-a3_track_2.mid
# Encoded brewert-fantasia6-a4_track_1.mid
# Encoded 11-thaleia_track_3.mid
# Encoded wardj-fantasia2a4_track_2.mid
# Encoded cranfordw-fantasia2-a5_track_1.mid
# Encoded laleonora_track_2.mid
# Encoded mancini-sonata8_track_1.mid
# Encoded barsantif-sonata1-op1_track_1.mid
# Encoded coprarioj-fantasia12-a5_track_1.mid
# Encoded hingestonj-fantazia8-a3_track_2.mid
# Encoded bassanog-fantasia14-a3_track_3.mid
# Encoded peersonm-fantasia1_track_4.mid
# Encoded ferraboscoa-fantasia03-a6_track_4.mid
# Encoded byrdw-fantasia2-a4_track_3.mid
# Encoded jenkinsj-pavin2-a6_track_3.mid
# Encoded lagratiosa_track_3.mid
# Encoded twv52-e1_track_6.mid
# Encoded coprarioj-fantasia06-a3_track_1.mid
# Encoded larizza_track_1.mid
# Encoded tomkinst-fantasia1-a6_track_1.mid
# Encoded flatconsort-vdgs3_track_3.mid
# Encoded peersonm-fantasia7_track_3.mid
# Encoded coprarioj-fantasia35-a5_track_1.mid
# Encoded jenkinsj-fantasia3-a5_track_1.mid
# Encoded jenkinsj-fantasia01-a6_track_2.mid
# Encoded jenkinsj-fantasia1-a5_track_4.mid
# Encoded canzona14_track_1.mid
# Encoded lupot-fantasia09-a6_track_5.mid
# Encoded jenkinsj-fantasia11-a4_track_2.mid
# Encoded morley_la_sirena_track_2.mid
# Encoded canzonquinta_track_2.mid
# Encoded wardj-fantasia11-a5_track_3.mid
# Encoded carwardenj-suite3-14-pavan_track_1.mid
# Encoded canzondecimasesta_track_2.mid
# Encoded canzonterza_track_4.mid
# Encoded whitew-fantasisa1-a6_track_6.mid
# Encoded lupot-fantasia7-a4_track_2.mid
# Encoded 21_infernum_track_2.mid
# Encoded duetto17_track_1.mid
# Encoded 15_pavan_track_3.mid
# Encoded jeffreysg-fantasia2-a3_track_3.mid
# Encoded tomkinst-fantasia10-a3_track_3.mid
# Encoded lupot-fantasia02-a6_track_5.mid
# Encoded micor-fantasia3-a3_track_2.mid
# Encoded twv42-g9_track_5.mid
# Encoded twv40-120_track_2.mid
# Encoded 21_infernum_track_5.mid
# Encoded wardj-fantasia4-a6_track_5.mid
# Encoded wardj-fantasia3-a5_track_3.mid
# Encoded 56_almayne_track_3.mid
# Encoded gibbonso-fantasia2-a6_track_3.mid
# Encoded brewert-21-corant_track_4.mid
# Encoded lupot-fantasia07-a6_track_1.mid
# Encoded brewert-12-almaine_track_3.mid
# Encoded 08-la_furta_track_4.mid
# Encoded 6-vixi_track_2.mid
# Encoded coprarioj-fantasia29-a5_track_2.mid
# Encoded lawesw-112-cmajor-aire_track_4.mid
# Encoded lupot-fantasia12-a6_track_5.mid
# Encoded weelkest-pavan6_track_1.mid
# Encoded jenkinsj-fantasia07-a6_track_4.mid
# Encoded hwv365_track_3.mid
# Encoded jenkinsj-pavin2-a6_track_4.mid
# Encoded duetto17_track_2.mid
# Encoded canzonottava_track_3.mid
# Encoded coprarioj-fantasia12-a5_track_5.mid
# Encoded coprarioj-fantasia05-a3_track_1.mid
# Encoded peersonm-almaine7_track_3.mid
# Encoded bassanog-fantasia07-a3_track_1.mid
# Encoded hingestonj-almande6-a3_track_3.mid
# Encoded bassanoj-fantasia1-a5_track_5.mid
# Encoded jenkinsj-fantasia07-a3_track_1.mid
# Encoded lupot-fantasia13-a4_track_1.mid
# Encoded coprarioj-fantasia04-a3_track_3.mid
# Encoded miltonj-fantasia1_track_4.mid
# Encoded flatconsort-vdgs10_track_3.mid
# Encoded 14-la_solda_track_2.mid
# Encoded twv52-a2_track_6.mid
# Encoded coleman-vdgs205-corant_track_1.mid
# Encoded lupot-fantasia12-a4_track_4.mid
# Encoded wardj-fantasia9-a5_track_4.mid
# Encoded barsantif-sonata3-op1_track_2.mid
# Encoded take-it-easy_track_1.mid
# Encoded peersonm-almaine2_track_5.mid
# Encoded 04_lullabie_track_5.mid
# Encoded twv52-a1_track_1.mid
# Encoded ferraboscoa-fantasia05-a6_track_5.mid
# Encoded jeffreysg-fantasia4-a3_track_1.mid
# Encoded hingestonj-fantasia8-a4_track_1.mid
# Encoded tallis-third-mode-melody-1_track_2.mid
# Encoded brewert-20-almaine_track_3.mid
# Encoded 16_galliard_track_1.mid
# Encoded labovia_track_4.mid
# Encoded 24_galliard_track_5.mid
# Encoded jenkinsj-fantasia13-a3_track_3.mid
# Encoded brewert-15-pavin_track_3.mid
# Encoded loeilletjb-sonata-opus26_track_5.mid
# Encoded colemanc-fantasia2-a6_track_2.mid
# Encoded twv40-142_4_track_2.mid
# Encoded 48_galliard_track_4.mid
# Encoded 1-desperavi_track_4.mid
# Encoded gibbonso-fantasia5-a3_track_3.mid
# Encoded brandenburg4-allegro_track_3.mid
# Encoded coprarioj-fantasia29-a5_track_4.mid
# Encoded carwardenj-suite4-22-corant_track_3.mid
# Encoded canzonquinta_track_4.mid
# Encoded 1-love_can_not_track_2.mid
# Encoded deeringr-fantasia1-a5_track_5.mid
# Encoded coprarioj-fantasia08-a5_track_1.mid
# Encoded canzonduodecima_track_4.mid
# Encoded twv42_h4_track_4.mid
# Encoded 65_heigh_ho_holiday_track_1.mid
# Encoded jenkinsj-fantasia03-a6_track_3.mid
# Encoded colemanc-fantasia5-a6_track_2.mid
# Encoded 18-lively_my_hearts_track_1.mid
# Encoded duetto03_track_1.mid
# Encoded ferraboscoa-fantasia08-a6_track_1.mid
# Encoded ravenscroftt-fantasia3-a5_track_2.mid
# Encoded fantaziaz736_1_track_3.mid
# Encoded croft-op3-no5_track_2.mid
# Encoded coleman-vdgs006-almaine_1_track_1.mid

# %%
print(len(all_tokens)) # 1641743 tokens in vocab
# Out:
# 1641743

# %%
print(list(token_set)) # vocab in tuples
print(len(token_set)) # vocab size = 2788
# Out:
# [(36, 480), (69, 1560), (60, 1740), (51, 1920), (0, 2220), (0, 13740), (44, 420), (81, 6000), (71, 2280), (79, 8520), (0, 59640), (0, 36600), (86, 3720), (67, 180), (58, 360), (70, 2400), (75, 300), (83, 6540), (66, 480), (52, 2760), (57, 660), (0, 9660), (0, 32700), (0, 21180), (48, 840), (81, 1920), (39, 1020), (72, 2100), (84, 2340), (56, 780), (67, 7620), (59, 1380), (45, 3660), (47, 960), (50, 1560), (36, 3840), (83, 2640), (74, 2820), (0, 5760), (76, 120), (88, 360), (79, 540), (82, 2760), (40, 1860), (67, 3720), (78, 840), (69, 1020), (60, 1200), (51, 1380), (0, 1680), (76, 7560), (66, 3840), (0, 13200), (0, 24720), (35, 60), (38, 660), (71, 1740), (29, 840), (62, 1920), (53, 2100), (70, 1860), (91, 900), (28, 960), (83, 6000), (74, 6180), (57, 120), (0, 9120), (43, 2400), (48, 300), (81, 1380), (39, 480), (72, 1560), (63, 2760), (84, 1800), (56, 240), (59, 840), (50, 1020), (47, 420), (41, 1200), (74, 2280), (0, 5220), (0, 16560), (0, 28080), (87, 120), (78, 300), (69, 480), (60, 660), (51, 840), (30, 1800), (0, 1140), (0, 12660), (38, 120), (68, 600), (71, 1200), (62, 1380), (48, 3660), (38, 11460), (39, 3840), (77, 2820), (56, 3780), (91, 360), (70, 1320), (28, 420), (52, 1680), (43, 1860), (81, 840), (38, 7560), (72, 1020), (84, 1260), (54, 2400), (80, 1140), (59, 300), (50, 480), (69, 3840), (83, 1560), (41, 660), (74, 1740), (0, 4680), (65, 1920), (44, 2880), (32, 840), (0, 16200), (82, 1680), (40, 780), (73, 1860), (62, 4740), (55, 2400), (31, 960), (64, 2040), (86, 6000), (69, 11460), (58, 2820), (60, 120), (51, 300), (75, 2580), (0, 600), (33, 1680), (66, 2760), (68, 60), (71, 660), (0, 46500), (62, 840), (63, 5760), (53, 1020), (77, 2280), (70, 780), (59, 3660), (61, 960), (50, 3840), (52, 1140), (46, 1920), (90, 120), (43, 1320), (81, 300), (72, 480), (84, 720), (89, 420), (54, 1860), (55, 5760), (80, 600), (60, 3660), (83, 1020), (51, 3840), (41, 120), (74, 1200), (0, 4140), (65, 1380), (49, 60), (64, 1680), (40, 240), (73, 1320), (55, 1860), (31, 23460), (67, 2100), (31, 420), (52, 4680), (42, 960), (0, 60), (0, 11580), (0, 23100), (81, 3840), (71, 120), (57, 2400), (57, 13920), (62, 300), (48, 2580), (53, 480), (86, 1560), (77, 1740), (67, 21060), (47, 2880), (70, 240), (61, 420), (76, 2040), (52, 600), (43, 780), (46, 1380), (71, 7560), (40, 3780), (84, 180), (80, 60), (36, 1680), (83, 480), (69, 2760), (74, 660), (0, 3600), (0, 15120), (65, 840), (44, 1800), (82, 600), (64, 1140), (86, 5100), (62, 3660), (73, 780), (55, 1320), (34, 480), (53, 3840), (67, 1560), (58, 1740), (70, 3780), (42, 420), (0, 11040), (66, 1680), (57, 1860), (84, 3720), (0, 91320), (86, 1020), (77, 1200), (56, 2160), (50, 2760), (76, 1500), (52, 60), (43, 240), (79, 1920), (0, 6960), (46, 840), (63, 600), (57, 112800), (54, 780), (45, 960), (69, 2220), (51, 2760), (74, 120), (0, 3060), (65, 300), (0, 37440), (0, 25920), (81, 6660), (82, 60), (38, 1860), (64, 600), (73, 240), (55, 780), (67, 1020), (53, 3300), (58, 1200), (74, 7560), (75, 960), (43, 3780), (0, 10500), (66, 1140), (33, 60), (81, 2760), (57, 1320), (39, 1860), (86, 480), (77, 660), (47, 1800), (69, 5760), (80, 2880), (85, 780), (76, 960), (65, 3840), (88, 1200), (41, 2400), (46, 300), (79, 1380), (0, 6420), (73, 3780), (63, 60), (54, 240), (45, 420), (78, 1500), (60, 2040), (69, 1680), (0, 2520), (44, 720), (66, 4680), (0, 14040), (35, 900), (71, 2400), (64, 60), (55, 240), (67, 480), (53, 2760), (54, 7680), (58, 660), (28, 1800), (61, 2880), (50, 5760), (75, 420), (43, 3240), (66, 600), (57, 780), (79, 4740), (46, 3660), (72, 2400), (48, 960), (48, 12480), (54, 3780), (55, 7680), (77, 120), (56, 1080), (55, 19200), (85, 240), (50, 1680), (83, 2760), (76, 420), (41, 1860), (0, 5880), (79, 840), (0, 17400), (0, 51960), (0, 28920), (82, 3060), (40, 2160), (69, 1320), (67, 3840), (78, 960), (36, 60), (42, 2880), (0, 1980), (44, 180), (0, 13500), (35, 360), (68, 1440), (38, 780), (71, 1860), (72, 5760), (62, 2040), (86, 3480), (29, 960), (53, 2220), (58, 120), (70, 2160), ...
# 2788

# %%
token_dict = {token: idx for idx, token in enumerate(sorted(token_set))}
print(token_dict)
print(len(token_dict))
# Out:
# {(0, 60): 0, (0, 120): 1, (0, 180): 2, (0, 240): 3, (0, 300): 4, (0, 360): 5, (0, 420): 6, (0, 480): 7, (0, 540): 8, (0, 600): 9, (0, 660): 10, (0, 720): 11, (0, 780): 12, (0, 840): 13, (0, 900): 14, (0, 960): 15, (0, 1020): 16, (0, 1080): 17, (0, 1140): 18, (0, 1200): 19, (0, 1260): 20, (0, 1320): 21, (0, 1380): 22, (0, 1440): 23, (0, 1500): 24, (0, 1560): 25, (0, 1620): 26, (0, 1680): 27, (0, 1740): 28, (0, 1800): 29, (0, 1860): 30, (0, 1920): 31, (0, 1980): 32, (0, 2040): 33, (0, 2100): 34, (0, 2160): 35, (0, 2220): 36, (0, 2280): 37, (0, 2340): 38, (0, 2400): 39, (0, 2460): 40, (0, 2520): 41, (0, 2580): 42, (0, 2640): 43, (0, 2700): 44, (0, 2760): 45, (0, 2820): 46, (0, 2880): 47, (0, 2940): 48, (0, 3000): 49, (0, 3060): 50, (0, 3120): 51, (0, 3180): 52, (0, 3240): 53, (0, 3300): 54, (0, 3360): 55, (0, 3420): 56, (0, 3480): 57, (0, 3540): 58, (0, 3600): 59, (0, 3660): 60, (0, 3720): 61, (0, 3780): 62, (0, 3840): 63, (0, 3900): 64, (0, 3960): 65, (0, 4020): 66, (0, 4080): 67, (0, 4140): 68, (0, 4200): 69, (0, 4260): 70, (0, 4320): 71, (0, 4380): 72, (0, 4440): 73, (0, 4500): 74, (0, 4560): 75, (0, 4620): 76, (0, 4680): 77, (0, 4740): 78, (0, 4800): 79, (0, 4860): 80, (0, 4920): 81, (0, 4980): 82, (0, 5040): 83, (0, 5100): 84, (0, 5160): 85, (0, 5220): 86, (0, 5280): 87, (0, 5340): 88, (0, 5400): 89, (0, 5460): 90, (0, 5520): 91, (0, 5580): 92, (0, 5640): 93, (0, 5760): 94, (0, 5820): 95, (0, 5880): 96, (0, 5940): 97, (0, 6000): 98, (0, 6060): 99, (0, 6120): 100, (0, 6180): 101, (0, 6240): 102, (0, 6300): 103, (0, 6420): 104, (0, 6480): 105, (0, 6540): 106, (0, 6600): 107, (0, 6660): 108, (0, 6720): 109, (0, 6780): 110, (0, 6840): 111, (0, 6900): 112, (0, 6960): 113, (0, 7020): 114, (0, 7080): 115, (0, 7140): 116, (0, 7200): 117, (0, 7260): 118, (0, 7320): 119, (0, 7380): 120, (0, 7440): 121, (0, 7560): 122, (0, 7620): 123, (0, 7680): 124, (0, 7740): 125, (0, 7800): 126, (0, 7860): 127, (0, 7920): 128, (0, 7980): 129, (0, 8100): 130, (0, 8160): 131, (0, 8220): 132, (0, 8280): 133, (0, 8400): 134, (0, 8460): 135, (0, 8640): 136, (0, 8700): 137, (0, 8760): 138, (0, 8820): 139, (0, 8880): 140, (0, 9000): 141, (0, 9060): 142, (0, 9120): 143, (0, 9240): 144, (0, 9360): 145, (0, 9420): 146, (0, 9540): 147, (0, 9600): 148, (0, 9660): 149, (0, 9720): 150, (0, 9780): 151, (0, 9840): 152, (0, 9900): 153, (0, 10080): 154, (0, 10140): 155, (0, 10200): 156, (0, 10260): 157, (0, 10320): 158, (0, 10380): 159, (0, 10440): 160, (0, 10500): 161, (0, 10560): 162, (0, 10620): 163, (0, 10680): 164, (0, 10800): 165, (0, 10860): 166, (0, 10980): 167, (0, 11040): 168, (0, 11160): 169, (0, 11220): 170, (0, 11280): 171, (0, 11400): 172, (0, 11520): 173, (0, 11580): 174, (0, 11640): 175, (0, 11700): 176, (0, 11760): 177, (0, 11820): 178, (0, 11880): 179, (0, 12000): 180, (0, 12240): 181, (0, 12300): 182, (0, 12480): 183, (0, 12540): 184, (0, 12600): 185, (0, 12660): 186, (0, 12720): 187, (0, 12780): 188, (0, 12960): 189, (0, 13020): 190, (0, 13140): 191, (0, 13200): 192, (0, 13320): 193, (0, 13440): 194, (0, 13500): 195, (0, 13560): 196, (0, 13620): 197, (0, 13680): 198, (0, 13740): 199, (0, 13860): 200, (0, 13920): 201, (0, 14040): 202, (0, 14100): 203, (0, 14160): 204, (0, 14400): 205, (0, 14460): 206, (0, 14640): 207, (0, 14760): 208, (0, 15000): 209, (0, 15120): 210, (0, 15180): 211, (0, 15300): 212, (0, 15360): 213, (0, 15420): 214, (0, 15480): 215, (0, 15540): 216, (0, 15840): 217, (0, 15900): 218, (0, 16200): 219, (0, 16320): 220, (0, 16380): 221, (0, 16560): 222, (0, 16800): 223, (0, 16920): 224, (0, 16980): 225, (0, 17280): 226, (0, 17340): 227, (0, 17400): 228, (0, 17460): 229, (0, 17760): 230, (0, 17820): 231, (0, 18000): 232, (0, 18060): 233, (0, 18300): 234, (0, 18360): 235, (0, 18420): 236, (0, 18720): 237, (0, 19080): 238, (0, 19140): 239, (0, 19200): 240, (0, 19260): 241, (0, 19320): 242, (0, 19380): 243, (0, 19440): 244, (0, 19860): 245, (0, 20160): 246, (0, 20220): 247, (0, 20520): 248, (0, 20700): 249, (0, 21120): 250, (0, 21180): 2 ...
# 2788

# %%
# Create token-to-ID mapping
token2id = {token: idx for idx, token in enumerate(sorted(token_set))}
id2token = {idx: token for token, idx in token2id.items()}  # Optional: for decoding

# %%
all_token_ids = tokens_to_ids(all_tokens, token2id)

# %%
print(len(all_token_ids)) # All tokens from their IDs
print(all_token_ids[:100])
# Out:
# 1641743
# [1856, 1959, 2010, 2111, 2013, 1962, 1850, 1735, 1856, 1735, 1741, 1692, 5, 2111, 2221, 2277, 2380, 2333, 2374, 2111, 2224, 2227, 2108, 2013, 1968, 1850, 2469, 2371, 2280, 2224, 2224, 2280, 2380, 2280, 2230, 2111, 2111, 2013, 1962, 1856, 5, 2111, 2221, 2277, 2380, 2333, 2374, 2111, 2224, 2227, 2108, 2013, 1968, 1850, 2469, 2371, 2280, 2224, 2224, 2280, 2380, 2280, 2230, 2111, 1847, 1959, 2016, 2108, 2224, 2013, 2019, 5, 1735, 1853, 1959, 2010, 2108, 2224, 2117, 2068, 1856, 1735, 11, 2013, 1919, 1850, 1741, 1850, 2280, 2224, 2111, 2068, 2466, 2371, 2221, 2277, 2108, 2224, 2280, 2224]

# %%
import torch

data = torch.tensor(all_token_ids, dtype=torch.long)
print(data.shape, data.dtype)
print(data[:100])
# Out:
# torch.Size([1641743]) torch.int64
# tensor([1856, 1959, 2010, 2111, 2013, 1962, 1850, 1735, 1856, 1735, 1741, 1692,
#            5, 2111, 2221, 2277, 2380, 2333, 2374, 2111, 2224, 2227, 2108, 2013,
#         1968, 1850, 2469, 2371, 2280, 2224, 2224, 2280, 2380, 2280, 2230, 2111,
#         2111, 2013, 1962, 1856,    5, 2111, 2221, 2277, 2380, 2333, 2374, 2111,
#         2224, 2227, 2108, 2013, 1968, 1850, 2469, 2371, 2280, 2224, 2224, 2280,
#         2380, 2280, 2230, 2111, 1847, 1959, 2016, 2108, 2224, 2013, 2019,    5,
#         1735, 1853, 1959, 2010, 2108, 2224, 2117, 2068, 1856, 1735,   11, 2013,
#         1919, 1850, 1741, 1850, 2280, 2224, 2111, 2068, 2466, 2371, 2221, 2277,
#         2108, 2224, 2280, 2224])

# %% [markdown]
# Splitting MIDI files into training and validation sets with a 0.1:0.9 ratio

# %%
# split the data into training and testing data with a ration of 0.9:0.1
n = int(0.9*len(data))
train_data = data[:n]
test_data = data[n:]

print(len(train_data)) # 0.9 * 1641743 = 1477568
print(len(test_data)) # 0.1 * 1641743 = 164175
# Out:
# 1477568
# 164175

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else test_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
from torch.utils.data import Dataset

class MIDITokenDataset(Dataset):
    def __init__(self, data, block_size):
        self.data = data
        self.block_size = block_size

    def __len__(self):
        return len(self.data) - self.block_size

    def __getitem__(self, idx):
        x = self.data[idx : idx + self.block_size]
        y = self.data[idx + 1 : idx + 1 + self.block_size]
        return {"input_ids": x, "labels": y}

# %%
from torch.utils.data import DataLoader

block_size = 128
batch_size = 32
n_embd = 128
n_head = 4
n_layer = 4
dropout = 0.1

eval_iters = 200

train_dataset = MIDITokenDataset(train_data, block_size=block_size)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %%
import torch.nn as nn
import torch.nn.functional as F

class Head(nn.Module):
    def __init__(self, head_size, n_embd, block_size, dropout=0.1):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer("tril", torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        v = self.value(x)
        wei = q @ k.transpose(-2, -1) / (k.size(-1) ** 0.5)

        wei = wei.masked_fill(self.tril[:T, :T] == 0, float("-inf"))
        wei = F.softmax(wei, dim=-1)
        return self.dropout(wei @ v)

class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, n_embd, block_size, dropout=0.1):
        super().__init__()
        head_size = n_embd // num_heads
        self.heads = nn.ModuleList([Head(head_size, n_embd, block_size, dropout) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.dropout(self.proj(torch.cat([h(x) for h in self.heads], dim=-1)))

class FeedForward(nn.Module):
    def __init__(self, n_embd, dropout=0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout)
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    def __init__(self, n_embd, n_head, block_size, dropout=0.1):
        super().__init__()
        self.sa = MultiHeadAttention(n_head, n_embd, block_size, dropout)
        self.ffwd = FeedForward(n_embd, dropout)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class TransformerMIDILanguageModel(nn.Module):
    def __init__(self, vocab_size, n_embd=128, n_head=4, n_layer=6, block_size=128, dropout=0.1):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head, block_size, dropout) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd)
        self.lm_head = nn.Linear(n_embd, vocab_size)
        self.block_size = block_size
        self.vocab_size = vocab_size

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=idx.device))

        x = self.blocks(tok_emb + pos_emb)
        x = self.ln_f(x)
        logits = self.lm_head(x)
        loss = None
        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.vocab_size), targets.view(-1), ignore_index=-100)
        return logits, loss

    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None, eos_token_id=None):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -self.block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature

            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)

            if eos_token_id is not None and idx_next.item() == eos_token_id:
                break

        return idx

# %%
vocab_size = len(token2id)

model = TransformerMIDILanguageModel(
    vocab_size=vocab_size,
    n_embd=n_embd,
    n_head=n_head,
    n_layer=n_layer,
    block_size=block_size,
    dropout=dropout
).to(device)

torch.manual_seed(1337)

print(sum(p.numel() for p in model.parameters()) / 1e6, "M parameters")
# Out:
# 1.524708 M parameters

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            _, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
learning_rate = 1e-4
max_iters = 20000
eval_interval = 100

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')
    _, loss = model(xb, yb)

    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
# Out:
# step 0: train loss 3.3903, val loss 3.4575
# step 100: train loss 3.3839, val loss 3.4364
# step 200: train loss 3.3597, val loss 3.4281
# step 300: train loss 3.3590, val loss 3.4236
# step 400: train loss 3.3357, val loss 3.4017
# step 500: train loss 3.3273, val loss 3.3985
# step 600: train loss 3.3070, val loss 3.3865
# step 700: train loss 3.2937, val loss 3.3872
# step 800: train loss 3.2933, val loss 3.3660
# step 900: train loss 3.2923, val loss 3.3597
# step 1000: train loss 3.2810, val loss 3.3353
# step 1100: train loss 3.2685, val loss 3.3419
# step 1200: train loss 3.2644, val loss 3.3359
# step 1300: train loss 3.2531, val loss 3.3153
# step 1400: train loss 3.2480, val loss 3.3177
# step 1500: train loss 3.2180, val loss 3.3188
# step 1600: train loss 3.2186, val loss 3.3151
# step 1700: train loss 3.2235, val loss 3.2924
# step 1800: train loss 3.2229, val loss 3.2807
# step 1900: train loss 3.1973, val loss 3.2842
# step 2000: train loss 3.1988, val loss 3.2885
# step 2100: train loss 3.2044, val loss 3.2668
# step 2200: train loss 3.1821, val loss 3.2648
# step 2300: train loss 3.1789, val loss 3.2455
# step 2400: train loss 3.1533, val loss 3.2569
# step 2500: train loss 3.1695, val loss 3.2473
# step 2600: train loss 3.1498, val loss 3.2519
# step 2700: train loss 3.1531, val loss 3.2340
# step 2800: train loss 3.1316, val loss 3.2418
# step 2900: train loss 3.1373, val loss 3.2231
# step 3000: train loss 3.1306, val loss 3.2307
# step 3100: train loss 3.1263, val loss 3.2252
# step 3200: train loss 3.1158, val loss 3.2146
# step 3300: train loss 3.1159, val loss 3.2058
# step 3400: train loss 3.1070, val loss 3.1999
# step 3500: train loss 3.1106, val loss 3.1990
# step 3600: train loss 3.1206, val loss 3.1881
# step 3700: train loss 3.1041, val loss 3.1852
# step 3800: train loss 3.1012, val loss 3.1804
# step 3900: train loss 3.0806, val loss 3.1786
# step 4000: train loss 3.1011, val loss 3.1811
# step 4100: train loss 3.0872, val loss 3.1764
# step 4200: train loss 3.0653, val loss 3.1546
# step 4300: train loss 3.0747, val loss 3.1621
# step 4400: train loss 3.0654, val loss 3.1604
# step 4500: train loss 3.0770, val loss 3.1654
# step 4600: train loss 3.0574, val loss 3.1618
# step 4700: train loss 3.0507, val loss 3.1540
# step 4800: train loss 3.0538, val loss 3.1518
# step 4900: train loss 3.0551, val loss 3.1435
# step 5000: train loss 3.0429, val loss 3.1389
# step 5100: train loss 3.0558, val loss 3.1452
# step 5200: train loss 3.0323, val loss 3.1464
# step 5300: train loss 3.0362, val loss 3.1436
# step 5400: train loss 3.0239, val loss 3.1501
# step 5500: train loss 3.0249, val loss 3.1278
# step 5600: train loss 3.0170, val loss 3.1350
# step 5700: train loss 3.0280, val loss 3.1345
# step 5800: train loss 3.0146, val loss 3.1156
# step 5900: train loss 3.0054, val loss 3.1147
# step 6000: train loss 3.0172, val loss 3.1124
# step 6100: train loss 3.0183, val loss 3.1157
# step 6200: train loss 3.0143, val loss 3.1202
# step 6300: train loss 3.0005, val loss 3.1219
# step 6400: train loss 2.9976, val loss 3.1094
# step 6500: train loss 3.0000, val loss 3.1050
# step 6600: train loss 3.0017, val loss 3.0874
# step 6700: train loss 2.9939, val loss 3.1176
# step 6800: train loss 2.9892, val loss 3.0884
# step 6900: train loss 2.9981, val loss 3.1075
# step 7000: train loss 2.9753, val loss 3.0961
# step 7100: train loss 2.9836, val loss 3.0955
# step 7200: train loss 2.9741, val loss 3.0967
# step 7300: train loss 2.9743, val loss 3.0843
# step 7400: train loss 2.9778, val loss 3.0662
# step 7500: train loss 2.9624, val loss 3.0863
# step 7600: train loss 2.9619, val loss 3.0673
# step 7700: train loss 2.9734, val loss 3.0739
# step 7800: train loss 2.9621, val loss 3.0658
# step 7900: train loss 2.9575, val loss 3.0664
# step 8000: train loss 2.9572, val loss 3.0773
# step 8100: train loss 2.9699, val loss 3.0600
# step 8200: train loss 2.9370, val loss 3.0637
# step 8300: train loss 2.9439, val loss 3.0693
# step 8400: train loss 2.9568, val loss 3.0630
# step 8500: train loss 2.9439, val loss 3.0632
# step 8600: train loss 2.9387, val loss 3.0488
# step 8700: train loss 2.9432, val loss 3.0565
# step 8800: train loss 2.9316, val loss 3.0604
# step 8900: train loss 2.9284, val loss 3.0423
# step 9000: train loss 2.9244, val loss 3.0478
# step 9100: train loss 2.9356, val loss 3.0388
# step 9200: train loss 2.9371, val loss 3.0517
# step 9300: train loss 2.9149, val loss 3.0559
# step 9400: train loss 2.9180, val loss 3.0439
# step 9500: train loss 2.9015, val loss 3.0430
# step 9600: train loss 2.9114, val loss 3.0498
# step 9700: train loss 2.9149, val loss 3.0356
# step 9800: train loss 2.9273, val loss 3.0485
# step 9900: train loss 2.9025, val loss 3.0243
# step 10000: train loss 2.9115, val loss 3.0284
# step 10100: train loss 2.9059, val loss 3.0555
# step 10200: train loss 2.8858, val loss 3.0294
# step 10300: train loss 2.8970, val loss 3.0242
# step 10400: train loss 2.9159, val loss 3.0161
# step 10500: train loss 2.9106, val loss 3.0108
# step 10600: train loss 2.8908, val loss 3.0053
# step 10700: train loss 2.8854, val loss 3.0136
# step 10800: train loss 2.8950, val loss 3.0146
# step 10900: train loss 2.8815, val loss 2.9943
# step 11000: train loss 2.8956, val loss 3.0123
# step 11100: train loss 2.8773, val loss 3.0054
# step 11200: train loss 2.8936, val loss 3.0120
# step 11300: train loss 2.8832, val loss 2.9930
# step 11400: train loss 2.8822, val loss 3.0079
# step 11500: train loss 2.8694, val loss 3.0208
# step 11600: train loss 2.8723, val loss 2.9822
# step 11700: train loss 2.8671, val loss 2.9986
# step 11800: train loss 2.8693, val loss 3.0019
# step 11900: train loss 2.8640, val loss 2.9887
# step 12000: train loss 2.8679, val loss 3.0045
# step 12100: train loss 2.8672, val loss 3.0015
# step 12200: train loss 2.8628, val loss 2.9944
# step 12300: train loss 2.8517, val loss 2.9955
# step 12400: train loss 2.8551, val loss 2.9834
# step 12500: train loss 2.8563, val loss 2.9883
# step 12600: train loss 2.8541, val loss 2.9921
# step 12700: train loss 2.8452, val loss 2.9894
# step 12800: train loss 2.8537, val loss 2.9759
# step 12900: train loss 2.8441, val loss 2.9800
# step 13000: train loss 2.8368, val loss 2.9764
# step 13100: train loss 2.8481, val loss 2.9681
# step 13200: train loss 2.8433, val loss 2.9701
# step 13300: train loss 2.8338, val loss 2.9819
# step 13400: train loss 2.8328, val loss 2.9535
# step 13500: train loss 2.8272, val loss 2.9811
# step 13600: train loss 2.8203, val loss 2.9615
# step 13700: train loss 2.8202, val loss 2.9573
# step 13800: train loss 2.8368, val loss 2.9605
# step 13900: train loss 2.8346, val loss 2.9546
# step 14000: train loss 2.8276, val loss 2.9653
# step 14100: train loss 2.8211, val loss 2.9657
# step 14200: train loss 2.8150, val loss 2.9515
# step 14300: train loss 2.8050, val loss 2.9653
# step 14400: train loss 2.8075, val loss 2.9667
# step 14500: train loss 2.8198, val loss 2.9436
# step 14600: train loss 2.8076, val loss 2.9418
# step 14700: train loss 2.8019, val loss 2.9496
# step 14800: train loss 2.8090, val loss 2.9428
# step 14900: train loss 2.8054, val loss 2.9587
# step 15000: train loss 2.8058, val loss 2.9259
# step 15100: train loss 2.7921, val loss 2.9275
# step 15200: train loss 2.7981, val loss 2.9426
# step 15300: train loss 2.7916, val loss 2.9205
# step 15400: train loss 2.7976, val loss 2.9377
# step 15500: train loss 2.7898, val loss 2.9371
# step 15600: train loss 2.7915, val loss 2.9144
# step 15700: train loss 2.7811, val loss 2.9297
# step 15800: train loss 2.7867, val loss 2.9311
# step 15900: train loss 2.7779, val loss 2.9272
# step 16000: train loss 2.7807, val loss 2.9406
# step 16100: train loss 2.7753, val loss 2.9065
# step 16200: train loss 2.7747, val loss 2.9288
# step 16300: train loss 2.7672, val loss 2.9123
# step 16400: train loss 2.7713, val loss 2.9284
# step 16500: train loss 2.7691, val loss 2.9162
# step 16600: train loss 2.7599, val loss 2.9276
# step 16700: train loss 2.7610, val loss 2.9248
# step 16800: train loss 2.7565, val loss 2.9194
# step 16900: train loss 2.7618, val loss 2.9098
# step 17000: train loss 2.7527, val loss 2.9095
# step 17100: train loss 2.7533, val loss 2.8920
# step 17200: train loss 2.7542, val loss 2.9000
# step 17300: train loss 2.7443, val loss 2.9092
# step 17400: train loss 2.7395, val loss 2.9063
# step 17500: train loss 2.7496, val loss 2.8952
# step 17600: train loss 2.7427, val loss 2.8904
# step 17700: train loss 2.7421, val loss 2.8986
# step 17800: train loss 2.7380, val loss 2.8884
# step 17900: train loss 2.7191, val loss 2.8889
# step 18000: train loss 2.7330, val loss 2.9095
# step 18100: train loss 2.7420, val loss 2.8940
# step 18200: train loss 2.7326, val loss 2.8854
# step 18300: train loss 2.7304, val loss 2.8757
# step 18400: train loss 2.7350, val loss 2.8923
# step 18500: train loss 2.7149, val loss 2.8620
# step 18600: train loss 2.7230, val loss 2.8843
# step 18700: train loss 2.7305, val loss 2.8789
# step 18800: train loss 2.7148, val loss 2.8754
# step 18900: train loss 2.7242, val loss 2.8735
# step 19000: train loss 2.7104, val loss 2.8698
# step 19100: train loss 2.7230, val loss 2.8843
# step 19200: train loss 2.7194, val loss 2.8768
# step 19300: train loss 2.7044, val loss 2.8598
# step 19400: train loss 2.7160, val loss 2.8755
# step 19500: train loss 2.7186, val loss 2.8765
# step 19600: train loss 2.6996, val loss 2.8642
# step 19700: train loss 2.6973, val loss 2.8597
# step 19800: train loss 2.6894, val loss 2.8707
# step 19900: train loss 2.7059, val loss 2.8508
# step 19999: train loss 2.7020, val loss 2.8412

# %%
start_token = token2id[(0, 480)]  # or any common starting token
context = torch.tensor([[start_token]], dtype=torch.long, device=device)

generated_ids = model.generate(context, max_new_tokens=500)[0].tolist()

# %%
print(generated_ids)
# Out:
# [7, 2226, 2070, 2121, 2070, 2113, 2070, 2121, 2113, 2226, 2384, 2376, 2226, 2113, 2234, 2121, 2023, 1876, 2113, 2226, 2282, 2226, 2113, 2250, 23, 2230, 2278, 2222, 2109, 1964, 1852, 11, 2476, 2376, 2282, 1964, 11, 2464, 2372, 2276, 2226, 2113, 7, 2468, 2370, 2220, 2464, 2066, 2109, 2070, 2224, 2107, 1848, 1960, 2222, 2109, 2222, 2226, 2109, 1733, 2278, 2222, 2113, 2019, 2011, 2222, 2109, 1733, 1848, 2011, 1733, 1848, 1848, 2011, 2011, 1962, 1845, 1733, 7, 2222, 2276, 2370, 2220, 2109, 1852, 1964, 1733, 1848, 1960, 1735, 1731, 1850, 1846, 1960, 2011, 1958, 2064, 2107, 2220, 2109, 2109, 2226, 2113, 2226, 2431, 2278, 2226, 11, 1850, 1958, 2064, 2109, 2220, 2329, 2222, 1846, 2107, 2220, 2278, 2222, 2111, 2219, 2328, 2372, 2335, 3, 2113, 2066, 1846, 1958, 2066, 2109, 2374, 2220, 2278, 2224, 2107, 2015, 7, 1850, 1958, 2011, 1848, 2464, 2372, 2462, 2370, 1958, 2276, 2372, 2464, 2464, 2468, 3, 2372, 2224, 2276, 2109, 1850, 2009, 3, 2466, 2370, 2329, 2374, 2220, 2107, 2226, 1960, 1585, 2370, 2462, 2370, 2278, 0, 2515, 2466, 2370, 2331, 0, 2551, 2613, 2464, 0, 2462, 2614, 0, 2329, 2372, 0, 2462, 2464, 0, 2370, 2372, 0, 2462, 2517, 2372, 0, 2276, 2220, 2109, 0, 2220, 2220, 2298, 3, 2553, 2614, 2464, 0, 2107, 2222, 0, 2329, 2372, 0, 2462, 2464, 0, 2431, 0, 2331, 0, 2220, 2339, 2219, 0, 2107, 2222, 0, 1731, 1960, 0, 2011, 0, 2220, 2331, 0, 2329, 2392, 0, 2343, 2343, 10, 2542, 0, 2223, 0, 2110, 0, 2219, 0, 2063, 0, 2219, 0, 2219, 0, 2106, 0, 2372, 2371, 2011, 0, 2220, 0, 2464, 2221, 2329, 2577, 0, 2220, 2343, 0, 2370, 2276, 2222, 0, 2278, 2372, 5, 2282, 3, 2109, 1960, 2010, 0, 1848, 1960, 0, 1959, 0, 1847, 0, 1482, 0, 2111, 0, 1849, 1731, 2111, 0, 2064, 2111, 0, 2064, 2111, 0, 2065, 0, 2185, 0, 1849, 1731, 0, 1688, 1583, 1482, 0, 1847, 0, 1484, 1389, 1392, 0, 1485, 0, 1390, 0, 1484, 1481, 1583, 1634, 0, 1636, 1583, 1243, 1732, 0, 1734, 1846, 1633, 1584, 0, 0, 1584, 5, 1485, 0, 1244, 0, 717, 162, 13, 2111, 0, 1960, 0, 1845, 1731, 1735, 1, 1731, 1583, 1633, 1692, 4, 2222, 2331, 2372, 2331, 2222, 2466, 0, 1536, 0, 1964, 846, 1483, 1585, 1497, 1583, 1633, 1735, 1, 2014, 4, 1816, 2221, 0, 2108, 0, 2108, 0, 2068, 0, 1963, 0, 2064, 2108, 0, 2111, 0, 2014, 1, 1846, 1959, 0, 2065, 1, 2107, 2221, 0, 2111, 0, 2221, 0, 2371, 0, 2221, 0, 2111, 0, 2224, 0, 2065, 0, 2125, 20, 2221, 0, 1743, 1, 2220, 2221, 0, 2463, 0, 2220, 2370, 2276, 2220, 2107, 2009, 1962, 1, 2107, 2224, 4, 2276, 2370, 2276, 2220, 2107, 2107, 2070, 2107, 2013, 0, 2108, 0, 2064, 2107, 2224, 0, 1846, 1958, 2013, 0, 1962, 0, 2020, 2111, 0, 1851, 0, 2231, 9, 2224, 0, 2462, 2369, 2275, 2180, 2009, 2009, 2276, 2220, 2220, 2111, 1, 2107, 2462, 2462, 2370, 2276, 2009, 2109, 2226]

# %%
metadata={
    "ticks_per_beat": 480,
    "time_signature": MetaMessage("time_signature", numerator=4, denominator=4),
    "key_signature": MetaMessage("key_signature", key="C"),
    "set_tempo": MetaMessage("set_tempo", tempo=500000)
}

decode_ids_to_midi(generated_ids, "generated_output.mid", metadata, id2token)
